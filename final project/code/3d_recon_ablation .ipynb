# %% [markdown]
# ## Cell1：导入所需的库文件

# %%
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import cv2
import pickle
import random
from typing import List, Dict, Any,Tuple
from scipy.spatial.transform import Rotation as R_scipy
import open3d as o3d
from contextlib import redirect_stdout
from feature_extraction import load_or_extract_features
from feature_matching import load_or_match_image_pairs, filter_two_view_geometry
from initial_recon import print_pose_info, pick_initial_pair
from pnp_recon import pnp_pose, visualize_with_open3d, triangulate_points,multi_view_triangulation,visualize_colored_point_cloud,register_frame_by_epipolar
from bundle_adjustment import BundleAdjustment,TorchBundleAdjustment
from metrics import reprojection_errors,reprojection_stats,track_length_stats,image_coverage_stats,points_per_camera_ratio
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### 指定所需要的变量路径

# %%
# User parameters: adjust these paths before running
IMAGE_FOLDER = r"D:\lyz\Python\CV\AI4701\final project\images"
INTRINSICS_FILE = r"D:\lyz\Python\CV\AI4701\final project\camera_intrinsic.txt"
OUTPUT_DIR = r"D:\lyz\Python\CV\AI4701\final project\ablation_output"
SAVE_FEATURES = False
LOAD_FEATURES = False
VERBOSE = True

# %% [markdown]
# ## Cell 2: Load Images and Intrinsics

# %%
def load_images(image_folder: str) -> List[str]:
    paths = []
    for root, dirs, files in os.walk(image_folder):
        # 1. 只保留图片文件
        image_files = [
            f for f in files
            if f.lower().endswith(('.png', '.jpg', '.jpeg'))
        ]
        # 2. 按文件名逆序排序（"163225" > "163224"）
        image_files.sort(reverse=True)
        # 3. 拼接完整路径
        for f in image_files:
            paths.append(os.path.join(root, f))
    return paths


def load_intrinsics(k_path: str) -> np.ndarray:
    if not os.path.exists(k_path):
        raise FileNotFoundError(f"相机内参文件未找到：{k_path}")
    K = np.loadtxt(k_path, dtype=np.float32)
    if K.shape != (3, 3):
        raise ValueError(f"相机内参形状错误，应为3x3，但得到: {K.shape}")
    return K

# %%
# Load at module level
image_paths = load_images(IMAGE_FOLDER)
image_paths = image_paths[:10]  # Limit to first 100 images for testing
K = load_intrinsics(INTRINSICS_FILE)

# %% [markdown]
# ## Cell 3: Feature Extraction and Matching

# %%
def run_feature_pipeline(paths: List[str], K: np.ndarray, output_dir: str,
                         save: bool, load: bool, verbose: bool=True):
    def _run_quiet(func, *args, **kwargs):
        if verbose:
            return func(*args, **kwargs)
        with open(os.devnull, 'w') as devnull:
            with redirect_stdout(devnull):
                return func(*args, **kwargs)

    print("Extracting features...")
    features = _run_quiet(
        load_or_extract_features,
        paths, method='sift_improved', save=save, load=load, output_dir=output_dir
    )

    print("Matching features...")
    raw_matches = _run_quiet(
        load_or_match_image_pairs,
        features, method='sift', save=save, load=load, output_dir=output_dir
    )

    # RANSAC filtering
    n = len(features)
    al_matches = [[[] for _ in range(n)] for __ in range(n)]
    for i in range(n):
        for j in range(n):
            if i == j: continue
            kp1, _ = features[i]
            kp2, _ = features[j]
            m = raw_matches[i][j]
            if len(m) < 4:
                continue
            inliers, _ = _run_quiet(filter_two_view_geometry, kp1, kp2, m, K)
            # # 1) 从 m（List[cv2.DMatch]）里取坐标
            # pts1 = np.float32([ kp1[mi.queryIdx].pt for mi in m ])  # (N,2)
            # pts2 = np.float32([ kp2[mi.trainIdx].pt for mi in m ])  # (N,2)

            # # 2) 用 Essential 矩阵 + RANSAC 得到 mask
            # #    参数 threshold 可以根据你的像素精度调，比如 1.0–2.0 像素
            # E, mask = cv2.findEssentialMat(
            #     pts1, pts2, 
            #     cameraMatrix=K,
            #     method=cv2.RANSAC,
            #     prob=0.999,
            #     threshold=1.0
            # )
            # # mask 是一个 N×1 的 ndarray，值为 1 表示 inlier，0 表示 outlier

            # # 3) 根据 mask 筛出 inliers matches
            # inliers = [ m[i] for i in range(len(m)) if mask[i,0] == 1 ]

            # 4) 存回你的 al_matches
            al_matches[i][j] = inliers

    # Flatten into pairs
    matches_list = []
    for i in range(n):
        for j in range(i+1, n):
            if len(al_matches[i][j]) >= 4:
                matches_list.append((i, j, al_matches[i][j]))

    return features, al_matches, matches_list

# Execute
features, al_matches, matches_list = run_feature_pipeline(
    image_paths, K, OUTPUT_DIR, SAVE_FEATURES, LOAD_FEATURES, VERBOSE
)
# Out:
# Extracting features...
# 开始提取特征…
# === 特征提取完成: 10/10 张图像有效 ===
# Matching features...
# [DEBUG] 未加载缓存，开始重新匹配（不保存）…
#
# === [SIFT] 两两特征匹配开始 ===
# Matching features: 4858 vs 4490 descriptors
# Found 1468 good matches out of 4858 total matches
# Match ratio: 30.2%
# Distance stats - Min: 0.05, Max: 0.41, Mean: 0.19
# Matching features: 4858 vs 4199 descriptors
# Found 1012 good matches out of 4858 total matches
# Match ratio: 20.8%
# Distance stats - Min: 0.08, Max: 0.39, Mean: 0.21
# Matching features: 4858 vs 4486 descriptors
# Found 572 good matches out of 4858 total matches
# Match ratio: 11.8%
# Distance stats - Min: 0.11, Max: 0.38, Mean: 0.23
# Matching features: 4858 vs 4835 descriptors
# Found 461 good matches out of 4858 total matches
# Match ratio: 9.5%
# Distance stats - Min: 0.11, Max: 0.44, Mean: 0.24
# Matching features: 4858 vs 4578 descriptors
# Found 373 good matches out of 4858 total matches
# Match ratio: 7.7%
# Distance stats - Min: 0.10, Max: 0.37, Mean: 0.25
# Matching features: 4858 vs 4677 descriptors
# Found 268 good matches out of 4858 total matches
# Match ratio: 5.5%
# Distance stats - Min: 0.13, Max: 0.41, Mean: 0.26
# Matching features: 4858 vs 4977 descriptors
# Found 283 good matches out of 4858 total matches
# Match ratio: 5.8%
# Distance stats - Min: 0.10, Max: 0.43, Mean: 0.25
# Matching features: 4858 vs 4402 descriptors
# Found 444 good matches out of 4858 total matches
# Match ratio: 9.1%
# Distance stats - Min: 0.10, Max: 0.41, Mean: 0.24
# Matching features: 4858 vs 5041 descriptors
# Found 442 good matches out of 4858 total matches
# Match ratio: 9.1%
# Distance stats - Min: 0.10, Max: 0.46, Mean: 0.24
# Matching features: 4490 vs 4858 descriptors
# Found 1463 good matches out of 4490 total matches
# Match ratio: 32.6%
# Distance stats - Min: 0.05, Max: 0.39, Mean: 0.19
# Matching features: 4490 vs 4199 descriptors
# Found 1549 good matches out of 4490 total matches
# Match ratio: 34.5%
# Distance stats - Min: 0.06, Max: 0.42, Mean: 0.19
# Matching features: 4490 vs 4486 descriptors
# Found 738 good matches out of 4490 total matches
# Match ratio: 16.4%
# Distance stats - Min: 0.07, Max: 0.39, Mean: 0.22
# Matching features: 4490 vs 4835 descriptors
# Found 564 good matches out of 4490 total matches
# Match ratio: 12.6%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.23
# Matching features: 4490 vs 4578 descriptors
# Found 481 good matches out of 4490 total matches
# Match ratio: 10.7%
# Distance stats - Min: 0.10, Max: 0.39, Mean: 0.24
# Matching features: 4490 vs 4677 descriptors
# Found 343 good matches out of 4490 total matches
# Match ratio: 7.6%
# Distance stats - Min: 0.12, Max: 0.38, Mean: 0.25
# Matching features: 4490 vs 4977 descriptors
# Found 373 good matches out of 4490 total matches
# Match ratio: 8.3%
# Distance stats - Min: 0.11, Max: 0.38, Mean: 0.24
# Matching features: 4490 vs 4402 descriptors
# Found 545 good matches out of 4490 total matches
# Match ratio: 12.1%
# Distance stats - Min: 0.10, Max: 0.38, Mean: 0.23
# Matching features: 4490 vs 5041 descriptors
# Found 565 good matches out of 4490 total matches
# Match ratio: 12.6%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.23
# Matching features: 4199 vs 4858 descriptors
# Found 1020 good matches out of 4199 total matches
# Match ratio: 24.3%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.21
# Matching features: 4199 vs 4490 descriptors
# Found 1521 good matches out of 4199 total matches
# Match ratio: 36.2%
# Distance stats - Min: 0.06, Max: 0.39, Mean: 0.19
# Matching features: 4199 vs 4486 descriptors
# Found 1004 good matches out of 4199 total matches
# Match ratio: 23.9%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.20
# Matching features: 4199 vs 4835 descriptors
# Found 720 good matches out of 4199 total matches
# Match ratio: 17.1%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.22
# Matching features: 4199 vs 4578 descriptors
# Found 627 good matches out of 4199 total matches
# Match ratio: 14.9%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.23
# Matching features: 4199 vs 4677 descriptors
# Found 460 good matches out of 4199 total matches
# Match ratio: 11.0%
# Distance stats - Min: 0.09, Max: 0.38, Mean: 0.23
# Matching features: 4199 vs 4977 descriptors
# Found 497 good matches out of 4199 total matches
# Match ratio: 11.8%
# Distance stats - Min: 0.08, Max: 0.41, Mean: 0.24
# Matching features: 4199 vs 4402 descriptors
# Found 721 good matches out of 4199 total matches
# Match ratio: 17.2%
# Distance stats - Min: 0.08, Max: 0.42, Mean: 0.21
# Matching features: 4199 vs 5041 descriptors
# Found 728 good matches out of 4199 total matches
# Match ratio: 17.3%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.22
# Matching features: 4486 vs 4858 descriptors
# Found 598 good matches out of 4486 total matches
# Match ratio: 13.3%
# Distance stats - Min: 0.11, Max: 0.39, Mean: 0.23
# Matching features: 4486 vs 4490 descriptors
# Found 738 good matches out of 4486 total matches
# Match ratio: 16.5%
# Distance stats - Min: 0.07, Max: 0.43, Mean: 0.22
# Matching features: 4486 vs 4199 descriptors
# Found 1012 good matches out of 4486 total matches
# Match ratio: 22.6%
# Distance stats - Min: 0.07, Max: 0.43, Mean: 0.20
# Matching features: 4486 vs 4835 descriptors
# Found 1261 good matches out of 4486 total matches
# Match ratio: 28.1%
# Distance stats - Min: 0.06, Max: 0.42, Mean: 0.20
# Matching features: 4486 vs 4578 descriptors
# Found 906 good matches out of 4486 total matches
# Match ratio: 20.2%
# Distance stats - Min: 0.06, Max: 0.38, Mean: 0.22
# Matching features: 4486 vs 4677 descriptors
# Found 697 good matches out of 4486 total matches
# Match ratio: 15.5%
# Distance stats - Min: 0.09, Max: 0.43, Mean: 0.23
# Matching features: 4486 vs 4977 descriptors
# Found 608 good matches out of 4486 total matches
# Match ratio: 13.6%
# Distance stats - Min: 0.08, Max: 0.39, Mean: 0.23
# Matching features: 4486 vs 4402 descriptors
# Found 923 good matches out of 4486 total matches
# Match ratio: 20.6%
# Distance stats - Min: 0.06, Max: 0.40, Mean: 0.22
# Matching features: 4486 vs 5041 descriptors
# Found 977 good matches out of 4486 total matches
# Match ratio: 21.8%
# Distance stats - Min: 0.07, Max: 0.41, Mean: 0.21
# Matching features: 4835 vs 4858 descriptors
# Found 478 good matches out of 4835 total matches
# Match ratio: 9.9%
# Distance stats - Min: 0.11, Max: 0.42, Mean: 0.24
# Matching features: 4835 vs 4490 descriptors
# Found 588 good matches out of 4835 total matches
# Match ratio: 12.2%
# Distance stats - Min: 0.08, Max: 0.43, Mean: 0.23
# Matching features: 4835 vs 4199 descriptors
# Found 744 good matches out of 4835 total matches
# Match ratio: 15.4%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.22
# Matching features: 4835 vs 4486 descriptors
# Found 1230 good matches out of 4835 total matches
# Match ratio: 25.4%
# Distance stats - Min: 0.06, Max: 0.42, Mean: 0.19
# Matching features: 4835 vs 4578 descriptors
# Found 1243 good matches out of 4835 total matches
# Match ratio: 25.7%
# Distance stats - Min: 0.05, Max: 0.41, Mean: 0.19
# Matching features: 4835 vs 4677 descriptors
# Found 1013 good matches out of 4835 total matches
# Match ratio: 21.0%
# Distance stats - Min: 0.07, Max: 0.42, Mean: 0.21
# Matching features: 4835 vs 4977 descriptors
# Found 789 good matches out of 4835 total matches
# Match ratio: 16.3%
# Distance stats - Min: 0.07, Max: 0.42, Mean: 0.22
# Matching features: 4835 vs 4402 descriptors
# Found 1051 good matches out of 4835 total matches
# Match ratio: 21.7%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.21
# Matching features: 4835 vs 5041 descriptors
# Found 1061 good matches out of 4835 total matches
# Match ratio: 21.9%
# Distance stats - Min: 0.07, Max: 0.42, Mean: 0.21
# Matching features: 4578 vs 4858 descriptors
# Found 360 good matches out of 4578 total matches
# Match ratio: 7.9%
# Distance stats - Min: 0.10, Max: 0.44, Mean: 0.25
# Matching features: 4578 vs 4490 descriptors
# Found 485 good matches out of 4578 total matches
# Match ratio: 10.6%
# Distance stats - Min: 0.10, Max: 0.39, Mean: 0.24
# Matching features: 4578 vs 4199 descriptors
# Found 633 good matches out of 4578 total matches
# Match ratio: 13.8%
# Distance stats - Min: 0.08, Max: 0.42, Mean: 0.23
# Matching features: 4578 vs 4486 descriptors
# Found 887 good matches out of 4578 total matches
# Match ratio: 19.4%
# Distance stats - Min: 0.06, Max: 0.41, Mean: 0.22
# Matching features: 4578 vs 4835 descriptors
# Found 1269 good matches out of 4578 total matches
# Match ratio: 27.7%
# Distance stats - Min: 0.05, Max: 0.43, Mean: 0.19
# Matching features: 4578 vs 4677 descriptors
# Found 1359 good matches out of 4578 total matches
# Match ratio: 29.7%
# Distance stats - Min: 0.04, Max: 0.40, Mean: 0.18
# Matching features: 4578 vs 4977 descriptors
# Found 1054 good matches out of 4578 total matches
# Match ratio: 23.0%
# Distance stats - Min: 0.06, Max: 0.42, Mean: 0.21
# Matching features: 4578 vs 4402 descriptors
# Found 1097 good matches out of 4578 total matches
# Match ratio: 24.0%
# Distance stats - Min: 0.07, Max: 0.42, Mean: 0.20
# Matching features: 4578 vs 5041 descriptors
# Found 832 good matches out of 4578 total matches
# Match ratio: 18.2%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.22
# Matching features: 4677 vs 4858 descriptors
# Found 265 good matches out of 4677 total matches
# Match ratio: 5.7%
# Distance stats - Min: 0.13, Max: 0.39, Mean: 0.25
# Matching features: 4677 vs 4490 descriptors
# Found 370 good matches out of 4677 total matches
# Match ratio: 7.9%
# Distance stats - Min: 0.12, Max: 0.41, Mean: 0.25
# Matching features: 4677 vs 4199 descriptors
# Found 472 good matches out of 4677 total matches
# Match ratio: 10.1%
# Distance stats - Min: 0.09, Max: 0.44, Mean: 0.23
# Matching features: 4677 vs 4486 descriptors
# Found 664 good matches out of 4677 total matches
# Match ratio: 14.2%
# Distance stats - Min: 0.07, Max: 0.43, Mean: 0.22
# Matching features: 4677 vs 4835 descriptors
# Found 1014 good matches out of 4677 total matches
# Match ratio: 21.7%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.21
# Matching features: 4677 vs 4578 descriptors
# Found 1346 good matches out of 4677 total matches
# Match ratio: 28.8%
# Distance stats - Min: 0.04, Max: 0.42, Mean: 0.18
# Matching features: 4677 vs 4977 descriptors
# Found 935 good matches out of 4677 total matches
# Match ratio: 20.0%
# Distance stats - Min: 0.07, Max: 0.49, Mean: 0.21
# Matching features: 4677 vs 4402 descriptors
# Found 859 good matches out of 4677 total matches
# Match ratio: 18.4%
# Distance stats - Min: 0.07, Max: 0.39, Mean: 0.22
# Matching features: 4677 vs 5041 descriptors
# Found 652 good matches out of 4677 total matches
# Match ratio: 13.9%
# Distance stats - Min: 0.09, Max: 0.40, Mean: 0.23
# Matching features: 4977 vs 4858 descriptors
# Found 261 good matches out of 4977 total matches
# Match ratio: 5.2%
# Distance stats - Min: 0.10, Max: 0.39, Mean: 0.24
# Matching features: 4977 vs 4490 descriptors
# Found 377 good matches out of 4977 total matches
# Match ratio: 7.6%
# Distance stats - Min: 0.11, Max: 0.41, Mean: 0.24
# Matching features: 4977 vs 4199 descriptors
# Found 493 good matches out of 4977 total matches
# Match ratio: 9.9%
# Distance stats - Min: 0.08, Max: 0.38, Mean: 0.23
# Matching features: 4977 vs 4486 descriptors
# Found 611 good matches out of 4977 total matches
# Match ratio: 12.3%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.23
# Matching features: 4977 vs 4835 descriptors
# Found 786 good matches out of 4977 total matches
# Match ratio: 15.8%
# Distance stats - Min: 0.07, Max: 0.39, Mean: 0.21
# Matching features: 4977 vs 4578 descriptors
# Found 1038 good matches out of 4977 total matches
# Match ratio: 20.9%
# Distance stats - Min: 0.06, Max: 0.42, Mean: 0.21
# Matching features: 4977 vs 4677 descriptors
# Found 935 good matches out of 4977 total matches
# Match ratio: 18.8%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.21
# Matching features: 4977 vs 4402 descriptors
# Found 1119 good matches out of 4977 total matches
# Match ratio: 22.5%
# Distance stats - Min: 0.03, Max: 0.41, Mean: 0.20
# Matching features: 4977 vs 5041 descriptors
# Found 852 good matches out of 4977 total matches
# Match ratio: 17.1%
# Distance stats - Min: 0.05, Max: 0.41, Mean: 0.21
# Matching features: 4402 vs 4858 descriptors
# Found 438 good matches out of 4402 total matches
# Match ratio: 10.0%
# Distance stats - Min: 0.10, Max: 0.39, Mean: 0.24
# Matching features: 4402 vs 4490 descriptors
# Found 563 good matches out of 4402 total matches
# Match ratio: 12.8%
# Distance stats - Min: 0.10, Max: 0.41, Mean: 0.23
# Matching features: 4402 vs 4199 descriptors
# Found 722 good matches out of 4402 total matches
# Match ratio: 16.4%
# Distance stats - Min: 0.08, Max: 0.39, Mean: 0.21
# Matching features: 4402 vs 4486 descriptors
# Found 916 good matches out of 4402 total matches
# Match ratio: 20.8%
# Distance stats - Min: 0.06, Max: 0.40, Mean: 0.21
# Matching features: 4402 vs 4835 descriptors
# Found 1051 good matches out of 4402 total matches
# Match ratio: 23.9%
# Distance stats - Min: 0.07, Max: 0.41, Mean: 0.21
# Matching features: 4402 vs 4578 descriptors
# Found 1096 good matches out of 4402 total matches
# Match ratio: 24.9%
# Distance stats - Min: 0.07, Max: 0.43, Mean: 0.20
# Matching features: 4402 vs 4677 descriptors
# Found 863 good matches out of 4402 total matches
# Match ratio: 19.6%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.22
# Matching features: 4402 vs 4977 descriptors
# Found 1126 good matches out of 4402 total matches
# Match ratio: 25.6%
# Distance stats - Min: 0.03, Max: 0.40, Mean: 0.20
# Matching features: 4402 vs 5041 descriptors
# Found 1228 good matches out of 4402 total matches
# Match ratio: 27.9%
# Distance stats - Min: 0.05, Max: 0.40, Mean: 0.20
# Matching features: 5041 vs 4858 descriptors
# Found 438 good matches out of 5041 total matches
# Match ratio: 8.7%
# Distance stats - Min: 0.10, Max: 0.41, Mean: 0.24
# Matching features: 5041 vs 4490 descriptors
# Found 573 good matches out of 5041 total matches
# Match ratio: 11.4%
# Distance stats - Min: 0.08, Max: 0.43, Mean: 0.23
# Matching features: 5041 vs 4199 descriptors
# Found 734 good matches out of 5041 total matches
# Match ratio: 14.6%
# Distance stats - Min: 0.07, Max: 0.43, Mean: 0.22
# Matching features: 5041 vs 4486 descriptors
# Found 967 good matches out of 5041 total matches
# Match ratio: 19.2%
# Distance stats - Min: 0.07, Max: 0.42, Mean: 0.21
# Matching features: 5041 vs 4835 descriptors
# Found 1055 good matches out of 5041 total matches
# Match ratio: 20.9%
# Distance stats - Min: 0.07, Max: 0.41, Mean: 0.21
# Matching features: 5041 vs 4578 descriptors
# Found 842 good matches out of 5041 total matches
# Match ratio: 16.7%
# Distance stats - Min: 0.07, Max: 0.43, Mean: 0.22
# Matching features: 5041 vs 4677 descriptors
# Found 668 good matches out of 5041 total matches
# Match ratio: 13.3%
# Distance stats - Min: 0.09, Max: 0.45, Mean: 0.23
# Matching features: 5041 vs 4977 descriptors
# Found 872 good matches out of 5041 total matches
# Match ratio: 17.3%
# Distance stats - Min: 0.05, Max: 0.44, Mean: 0.22
# Matching features: 5041 vs 4402 descriptors
# Found 1222 good matches out of 5041 total matches
# Match ratio: 24.2%
# Distance stats - Min: 0.05, Max: 0.40, Mean: 0.20
# [Geo] E-inliers: 1302/1468
# [Geo] H-inliers: 164/1302  ratio=0.13
# [Geo] Pose-inliers: 1223/1302
# [Geo] final inliers: 1223
# [Geo] E-inliers: 887/1012
# [Geo] H-inliers: 89/887  ratio=0.10
# [Geo] Pose-inliers: 886/887
# [Geo] final inliers: 886
# [Geo] E-inliers: 428/572
# [Geo] H-inliers: 43/428  ratio=0.10
# [Geo] Pose-inliers: 426/428
# [Geo] final inliers: 426
# [Geo] E-inliers: 355/461
# [Geo] H-inliers: 38/355  ratio=0.11
# [Geo] Pose-inliers: 355/355
# [Geo] final inliers: 355
# [Geo] E-inliers: 297/373
# [Geo] H-inliers: 35/297  ratio=0.12
# [Geo] Pose-inliers: 297/297
# [Geo] final inliers: 297
# [Geo] E-inliers: 188/268
# [Geo] H-inliers: 23/188  ratio=0.12
# [Geo] Pose-inliers: 188/188
# [Geo] final inliers: 188
# [Geo] E-inliers: 198/283
# [Geo] H-inliers: 29/198  ratio=0.15
# [Geo] Pose-inliers: 198/198
# [Geo] final inliers: 198
# [Geo] E-inliers: 326/444
# [Geo] H-inliers: 33/326  ratio=0.10
# [Geo] Pose-inliers: 326/326
# [Geo] final inliers: 326
# [Geo] E-inliers: 322/442
# [Geo] H-inliers: 27/322  ratio=0.08
# [Geo] Pose-inliers: 322/322
# [Geo] final inliers: 322
# [Geo] E-inliers: 1278/1463
# [Geo] H-inliers: 175/1278  ratio=0.14
# [Geo] Pose-inliers: 1173/1278
# [Geo] final inliers: 1173
# [Geo] E-inliers: 1413/1549
# [Geo] H-inliers: 211/1413  ratio=0.15
# [Geo] Pose-inliers: 1345/1413
# [Geo] final inliers: 1345
# [Geo] E-inliers: 533/738
# [Geo] H-inliers: 61/533  ratio=0.11
# [Geo] Pose-inliers: 523/533
# [Geo] final inliers: 523
# [Geo] E-inliers: 384/563
# [Geo] H-inliers: 38/384  ratio=0.10
# [Geo] Pose-inliers: 384/384
# [Geo] final inliers: 384
# [Geo] E-inliers: 540/722
# [Geo] H-inliers: 71/540  ratio=0.13
# [Geo] Pose-inliers: 540/540
# [Geo] final inliers: 540
# [Geo] E-inliers: 619/916
# [Geo] H-inliers: 66/619  ratio=0.11
# [Geo] Pose-inliers: 619/619
# [Geo] final inliers: 619
# [Geo] E-inliers: 786/1051
# [Geo] H-inliers: 114/786  ratio=0.15
# [Geo] Pose-inliers: 769/786
# [Geo] final inliers: 769
# [Geo] E-inliers: 846/1096
# [Geo] H-inliers: 115/846  ratio=0.14
# [Geo] Pose-inliers: 825/846
# [Geo] final inliers: 825
# [Geo] E-inliers: 727/863
# [Geo] H-inliers: 75/727  ratio=0.10
# [Geo] Pose-inliers: 722/727
# [Geo] final inliers: 722
# [Geo] E-inliers: 960/1126
# [Geo] H-inliers: 137/960  ratio=0.14
# [Geo] Pose-inliers: 907/960
# [Geo] final inliers: 907
# [Geo] E-inliers: 999/1228
# [Geo] H-inliers: 149/999  ratio=0.15
# [Geo] Pose-inliers: 882/999
# [Geo] final inliers: 882
# [Geo] E-inliers: 316/438
# [Geo] H-inliers: 40/316  ratio=0.13
# [Geo] Pose-inliers: 316/316
# [Geo] final inliers: 316
# [Geo] E-inliers: 381/573
# [Geo] H-inliers: 44/381  ratio=0.12
# [Geo] Pose-inliers: 381/381
# [Geo] final inliers: 381
# [Geo] E-inliers: 511/734
# [Geo] H-inliers: 62/511  ratio=0.12
# [Geo] Pose-inliers: 511/511
# [Geo] final inliers: 511
# [Geo] E-inliers: 575/967
# [Geo] H-inliers: 75/575  ratio=0.13
# [Geo] Pose-inliers: 574/575
# [Geo] final inliers: 574
# [Geo] E-inliers: 730/1055
# [Geo] H-inliers: 84/730  ratio=0.12
# [Geo] Pose-inliers: 671/730
# [Geo] final inliers: 671
# [Geo] E-inliers: 655/842
# [Geo] H-inliers: 73/655  ratio=0.11
# [Geo] Pose-inliers: 638/655
# [Geo] final inliers: 638
# [Geo] E-inliers: 519/668
# [Geo] H-inliers: 62/519  ratio=0.12
# [Geo] Pose-inliers: 518/519
# [Geo] final inliers: 518
# [Geo] E-inliers: 688/872
# [Geo] H-inliers: 63/688  ratio=0.09
# [Geo] Pose-inliers: 686/688
# [Geo] final inliers: 686
# [Geo] E-inliers: 1049/1222
# [Geo] H-inliers: 125/1049  ratio=0.12
# [Geo] Pose-inliers: 923/1049
# [Geo] final inliers: 923

# %% [markdown]
# ## Cell 4: Initial Pose Estimation

# %%
def initialize_reconstruction(K: np.ndarray,
                              al_matches: List[List[List[cv2.DMatch]]],
                              features: List[Tuple[List[cv2.KeyPoint], np.ndarray]]):
    print("Estimating initial pose...")
    keypoints = [kp for kp, _ in features]
    i, j, R, t, inliers = pick_initial_pair(K, al_matches, keypoints=keypoints)
    print(f"Initial pair: {i}, {j}")
    print_pose_info(R, t, len(inliers), len(inliers))
    return i, j, R, t, inliers

init_i, init_j, R0, t0, init_inliers = initialize_reconstruction(K, al_matches, features)
print("Initial pair selected:", init_i, init_j)
# Out:
# Estimating initial pose...
# Initial pair: 3, 4
# ============================================================
# SCENE INITIALIZATION RESULTS
# ============================================================
#
# 1. Feature Matching:
#    - Total matches: 746
#    - Inlier matches: 746
#    - Inlier ratio: 1.000
#
# 2. Rotation Matrix (R):
# [[ 9.99175463e-01 -1.12709648e-04 -4.06002662e-02]
#  [ 1.18079132e-03  9.99653812e-01  2.62842386e-02]
#  [ 4.05832484e-02 -2.63105067e-02  9.98829694e-01]]
#
# 3. Translation Vector (t):
# [ 0.98728219 -0.01739318  0.1580233 ]
#
# 4. Rotation as Rodrigues vector: [-0.02630764 -0.0406076   0.000647  ]
# 5. Rotation in degrees: [-1.50731662 -2.32664424  0.03707054]
# 6. Translation distance (normalized): 1.0000
# 7. Total rotation angle: 2.77 degrees
# ============================================================
# Initial pair selected: 3 4

# %%
# %% 
# 7. Triangulate initial 3D points between camera init_i (ID 0) and init_j (ID 1)
kp_i, _ = features[init_i]
kp_j, _ = features[init_j]


pts3d, valid_idxs = triangulate_points(
    init_inliers, 
    kp_i, 
    kp_j, 
    K,
    np.eye(3),                # cam0 是世界坐标
    np.zeros((3,1)),         
    R0, 
    t0
)

print(f"Triangulated {pts3d.shape[0]} 3D points from the initial pair.")


# 8. 构建点云字典和观测字典
#    points_3d: pid -> [x, y, z]
#    point_observations: pid -> {cam_idx: (u,v), ...}
points_3d = {}
point_observations = {}

for pid, match_idx in enumerate(valid_idxs):
    # match_idx 是 init_inliers 中的下标
    m = init_inliers[match_idx]
    # 存坐标
    points_3d[pid] = pts3d[pid]
    # 存图像观测
    pt_i = kp_i[m.queryIdx].pt
    pt_j = kp_j[m.trainIdx].pt
    point_observations[pid] = {
        init_i: pt_i,
        init_j: pt_j
    }

print(f"Built observations for {len(points_3d)} points.")
# Out:
# Triangulated 746 3D points from the initial pair.
# Built observations for 746 points.

# %%
obs_index = {}
for pid, match_idx in enumerate(valid_idxs):
    m = init_inliers[match_idx]
    obs_index[(init_i, m.queryIdx)] = pid
    obs_index[(init_j, m.trainIdx)] = pid

# %% [markdown]
# ## Cell 5: Incremental SfM Reconstruction

# %%
def generate_bounce_path(
    num_images: int,
    begin: int,
    step: int = 10,
    p_jump: float = 0.01
) -> List[int]:
    """
    在 [0, num_images-1] 上以 step 为步长折返行走，同时
    以 p_jump 的概率做一次随机跳跃，以保证所有索引都有机会被访问。
    
    Args:
        num_images: 总图像数量 N
        begin:      起始索引
        step:       固定步长
        p_jump:     每一步有 p_jump 的概率随机跳到任意一个索引

    Returns:
        path: 访问序列，包含 0…num_images-1 中每个索引一次
    """
    visited = set()
    path = []
    pos = begin
    delta = step

    while len(visited) < num_images:
        # 随机跳跃
        if random.random() < p_jump:
            pos = random.randrange(num_images)
            # 随机换个方向
            delta = step if random.random() < 0.5 else -step
        else:
            # 折返逻辑
            if pos < 0:
                pos = -pos
                delta = -delta
            elif pos > num_images - 1:
                pos = 2*(num_images-1) - pos
                delta = -delta

        # 记录新索引
        if pos not in visited:
            visited.add(pos)
            path.append(pos)

        pos += delta

    return path

# %%
# 测试一下
order = generate_bounce_path(len(image_paths),begin=init_i , step=3)
print("访问顺序：", order)
# 例如： [0, 5, 10, 15, 19, 14, 9, 4, 0, 6, 12, 18, 23, ...]（直到覆盖所有）
# Out:
# 访问顺序： [3, 6, 9, 0, 7, 4, 1, 2, 5, 8]

# %%
anchor_idxs  = [init_i, init_j]
camera_poses = {
    init_i: {'R': np.eye(3), 't': np.zeros((3,1))},
    init_j: {'R': R0,        't': t0}
}
# points_3d, point_observations, obs_index 都已准备好

# 2. 准备可变顺序列表，从 init_i 开始
start = order.index(init_i)
order_list = order[start:]  # e.g. [init_i, next, next, ...]
# 我们用 idx_ptr 来遍历 order_list
idx_ptr = 1
iteration = 1  

# 3. 增量主循环
while idx_ptr < len(order_list):
    prev_idx = order_list[idx_ptr - 1]
    curr_idx = order_list[idx_ptr]

    # 3.1 如果前一帧还没注册，直接删掉这帧
    if prev_idx not in camera_poses:
        if VERBOSE:
            print(f"跳过 {prev_idx}->{curr_idx}：没有已知位姿，移除 {curr_idx}")
        order_list.pop(idx_ptr)
        continue

    # 3.2 聚合所有 anchors 的 2D–3D 对应
    kp_curr, _ = features[curr_idx]
    img_pts, obj_pts, corr = [], [], []
    for anchor in anchor_idxs:
        kp_a, _ = features[anchor]
        for m in al_matches[anchor][curr_idx]:
            key = (anchor, m.queryIdx)
            if key in obs_index:
                pid = obs_index[key]
                img_pts.append(kp_curr[m.trainIdx].pt)
                obj_pts.append(points_3d[pid])
                corr.append(m)
    # 如果对应太少，删掉这帧
    if len(obj_pts) < 4:
        if VERBOSE:
            print(f"跳过 图 {curr_idx}：2D–3D 对应 < 4 ({len(obj_pts)})，移除 {curr_idx}")
        order_list.pop(idx_ptr)
        continue

    # 3.3 PnP 注册
    # Rn, tn, inlier_mask = pnp_pose(img_pts, obj_pts, K)
    Rn, tn, inlier_mask = register_frame_by_epipolar(
        prev_idx, curr_idx,
        al_matches, features, K
    )
    if Rn is None:
        if VERBOSE:
            print(f"跳过 {prev_idx}->{curr_idx}：对极注册失败")
        order_list.pop(idx_ptr)
        continue
    camera_poses[curr_idx] = {'R': Rn, 't': tn}
    if VERBOSE:
        print(f"注册帧 {curr_idx}：PnP 内点 {int(inlier_mask.sum())}/{len(obj_pts)}")

    # 3.4 多视图三角化
    new_pts = multi_view_triangulation(
        new_idx=curr_idx,
        anchor_idxs=anchor_idxs,
        features=features,
        al_matches=al_matches,
        camera_poses=camera_poses,
        points_3d=points_3d,
        K=K
    )

    # 3.5 更新全局点云和观测
    for pid, X, match_map in new_pts:
        points_3d[pid] = X
        obs = {}
        for cam_idx, m in match_map.items():
            kpt = m.trainIdx if cam_idx == curr_idx else m.queryIdx
            uv  = features[cam_idx][0][kpt].pt
            obs[cam_idx] = uv
            obs_index[(cam_idx, kpt)] = pid
        point_observations[pid] = obs
        
    if VERBOSE:
        print(f"  新增 {len(new_pts)} 点，总共 {len(points_3d)} 点")

    # 3.5.5 局部 Bundle Adjustment
    # 选出本地要优化的相机和点
    if iteration % 5 == 0:
        local_cams = anchor_idxs.copy()      # e.g. 最近 5 帧
        # 找到这些相机观测到的所有点 pid
        local_pts = set()
        for pid, obs in point_observations.items():
            if any(c in local_cams for c in obs):
                local_pts.add(pid)
        local_pts = sorted(local_pts)

        # 构造 BA 输入：齐次相机矩阵数组 + 点坐标数组 + obs_uv, cam_idxs, pt_idxs
        # 1) 相机矩阵列表
        cam_mats_local = []
        cam_idx_map    = {}  # 原全局索引 → 本地 BA 内索引
        for i, c in enumerate(local_cams):
            cam_pose = camera_poses[c]
            T = np.eye(4, dtype=np.float64)
            T[:3,:3] = cam_pose['R']
            T[:3, 3] = cam_pose['t'].reshape(3)
            cam_mats_local.append(T)
            cam_idx_map[c] = i
        cam_mats_local = np.stack(cam_mats_local, axis=0)  # (Nc_local,4,4)

        # 2) 点坐标数组 + pid → 本地点索引
        pts_local = np.vstack([points_3d[pid] for pid in local_pts])  # (Np_local,3)
        pt_idx_map = {pid:i for i,pid in enumerate(local_pts)}

        # 3) 观测展平（仅保留本地 cams & pts）
        obs_uv_ba   = []
        cam_idxs_ba = []
        pt_idxs_ba  = []
        for pid in local_pts:
            for c, uv in point_observations[pid].items():
                if c in cam_idx_map:
                    obs_uv_ba  .append(uv)
                    cam_idxs_ba.append(cam_idx_map[c])
                    pt_idxs_ba .append(pt_idx_map[pid])
        obs_uv_ba   = np.array(obs_uv_ba,   dtype=np.float64)
        cam_idxs_ba = np.array(cam_idxs_ba, dtype=np.int64)
        pt_idxs_ba  = np.array(pt_idxs_ba,  dtype=np.int64)

        # 4) 运行本地 BA
        ba = TorchBundleAdjustment(
            camera_intrinsics=K,
            init_cameras=cam_mats_local,
            init_points=pts_local
        )
        opt_cams, opt_pts, info = ba.optimize(
            cameras=cam_mats_local,
            points_3d=pts_local,
            observations=obs_uv_ba,
            camera_indices=cam_idxs_ba,
            point_indices=pt_idxs_ba
        )

        # 5) 把优化结果写回全局
        # 5.1 相机
        for i, c in enumerate(local_cams):
            Topt = opt_cams[i]
            camera_poses[c]['R'] = Topt[:3,:3]
            camera_poses[c]['t'] = Topt[:3,3].reshape(3,1)
        # 5.2 点
        for i, pid in enumerate(local_pts):
            points_3d[pid] = opt_pts[i]

        if VERBOSE:
            print(f"  局部 BA 完成，优化 {len(local_cams)} 台相机和 {len(local_pts)} 个点")

    # 3.6 更新 anchor 队列（RFU：最近 5 帧）
    anchor_idxs.append(curr_idx)
    if len(anchor_idxs) > 5:
        dropped = anchor_idxs.pop(0)
        if VERBOSE:
            print(f"  anchor 满 {5}，丢弃最早帧 {dropped}")

    # 3.7 前进到下一帧
    idx_ptr += 1
    iteration += 1

print("增量重建完成")
print(f"相机数: {len(camera_poses)}, 三维点数: {len(points_3d)}")
# Out:
# 注册帧 6：PnP 内点 399/678
#   新增 474 点，总共 1220 点
# 注册帧 9：PnP 内点 448/1014
#   新增 28 点，总共 1248 点
# 注册帧 0：PnP 内点 291/580
#   新增 33 点，总共 1281 点
# 注册帧 7：PnP 内点 178/917
#   新增 1 点，总共 1282 点
#   anchor 满 5，丢弃最早帧 3
# 注册帧 4：PnP 内点 562/372
#   新增 0 点，总共 1282 点
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[
]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[2617.7776  2596.0955 ]
#  [ 263.01782 1434.7637 ]
#  [1411.9141  1107.7562 ]], pred_uv: [[2617.3591  2596.5122 ]
#  [ 261.07715 1433.0405 ]
#  [1473.0372  1130.6697 ]]
# [rodrigues] input rvecs shape: torch.Size([60, 3])
# [rodrigues] output R shape: torch.Size([60, 3, 3])
# [forward] batch obs_uv shape: torch.Size([60, 2]), pred_uv shape: torch.Size([60, 2])
# [forward] sample obs_uv: [[2233.2275  1044.7665 ]
#  [2530.9104   669.63086]
#  [ 653.18115 1850.6819 ]], pred_uv: [[2232.8262 1045.1692]
#  [2530.6777  670.0725]
#  [ 652.7417 1850.6622]]
# [optimize][Adam] epoch 10/10, loss = 4283229.9062
# [optimize] Starting LBFGS refinement...
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[796.98145 684.5525 ]
#  [724.90125 587.4144 ]
#  [724.94604 587.35394]]
# [optimize][LBFGS] current loss = 4219660.5000
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[-433.31396  236.80286]
#  [-539.85913  107.77368]
#  [-539.7993   107.70447]]
# [optimize][LBFGS] current loss = 846501120.0000
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[794.651   683.68506]
#  [722.52783 586.50146]
#  [722.5725  586.441  ]]
# [optimize][LBFGS] current loss = 4212647.0000
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[794.12134 683.4803 ]
#  [721.9889  586.28534]
#  [722.03345 586.2249 ]]
# [optimize][LBFGS] current loss = 4211045.5000
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[792.00134 682.63   ]
#  [719.8357  585.38715]
#  [719.8804  585.32654]]
# [optimize][LBFGS] current loss = 4202880.0000
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[789.8788 681.7005]
#  [717.6864 584.4028]
#  [717.7311 584.3423]]
# [optimize][LBFGS] current loss = 4189759.5000
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[785.43835 679.5368 ]
#  [713.20715 582.10406]
#  [713.25195 582.0437 ]]
# [optimize][LBFGS] current loss = 4148151.7500
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[778.73157 675.7785 ]
#  [706.48035 578.0984 ]
#  [706.52515 578.03796]]
# [optimize][LBFGS] current loss = 4053154.5000
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[768.1852  668.77   ]
#  [695.9877  570.6017 ]
#  [696.03296 570.5413 ]]
# [optimize][LBFGS] current loss = 3831001.5000
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[755.0437  658.03485]
#  [683.07263 559.0709 ]
#  [683.1183  559.01056]]
# [optimize][LBFGS] current loss = 3409912.5000
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[740.0032  645.40314]
#  [668.3557  545.4216 ]
#  [668.4021  545.3614 ]]
# [optimize][LBFGS] current loss = 2711646.7500
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[664.93555 583.9859 ]
#  [591.2506  481.28613]
#  [591.2976  481.22498]]
# [optimize][LBFGS] current loss = 2325779.7500
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[660.44324 625.2519 ]
#  [587.416   522.9941 ]
#  [587.46313 522.93335]]
# [optimize][LBFGS] current loss = 853088.6250
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[679.2035  631.5252 ]
#  [606.2373  529.9171 ]
#  [606.28394 529.8563 ]]
# [optimize][LBFGS] current loss = 312020.5000
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[688.64624 632.0318 ]
#  [615.5664  530.6903 ]
#  [615.6129  530.62946]]
# [optimize][LBFGS] current loss = 74589.4609
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[687.329  631.2665]
#  [614.2162 529.8762]
#  [614.2626 529.8153]]
# [optimize][LBFGS] current loss = 70788.7891
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[685.85876 630.4932 ]
#  [612.6926  529.059  ]
#  [612.73926 528.9983 ]]
# [optimize][LBFGS] current loss = 55023.5898
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[683.65466 631.4201 ]
#  [610.3585  530.02936]
#  [610.4048  529.9685 ]]
# [optimize][LBFGS] current loss = 62772.9844
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[684.699   631.3133 ]
#  [611.43616 529.9292 ]
#  [611.4824  529.8683 ]]
# [optimize][LBFGS] current loss = 43666.2578
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[685.1494  631.5866 ]
#  [611.89575 530.2204 ]
#  [611.94214 530.1594 ]]
# [optimize][LBFGS] current loss = 43299.9844
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[685.4297  631.8382 ]
#  [612.1836  530.48456]
#  [612.23    530.4236 ]]
# [optimize][LBFGS] current loss = 41864.6328
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[686.11633 631.55786]
#  [612.9214  530.1831 ]
#  [612.96765 530.1221 ]]
# [optimize][LBFGS] current loss = 41527.5664
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[685.8036  631.34204]
#  [612.6057  529.95154]
#  [612.6522  529.89056]]
# [optimize][LBFGS] current loss = 40396.9844
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[685.51184 631.19293]
#  [612.3075  529.7923 ]
#  [612.3539  529.73126]]
# [optimize][LBFGS] current loss = 40245.3164
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[685.37915 630.79333]
#  [612.1843  529.3644 ]
#  [612.2307  529.3034 ]]
# [optimize][LBFGS] current loss = 39009.5781
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[684.45483 631.2924 ]
#  [611.19055 529.8907 ]
#  [611.2368  529.8295 ]]
# [optimize][LBFGS] current loss = 38600.0156
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[685.26196 631.2103 ]
#  [612.0349  529.80725]
#  [612.0813  529.74615]]
# [optimize][LBFGS] current loss = 38247.5703
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[685.34106 631.235  ]
#  [612.1166  529.8337 ]
#  [612.16296 529.7727 ]]
# [optimize][LBFGS] current loss = 38210.1562
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[685.65955 631.36957]
#  [612.4374  529.977  ]
#  [612.4835  529.91595]]
# [optimize][LBFGS] current loss = 37846.3789
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[685.9353  631.52313]
#  [612.70435 530.1365 ]
#  [612.75085 530.0756 ]]
# [optimize][LBFGS] current loss = 36991.5625
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[686.405   631.6655 ]
#  [613.1561  530.27527]
#  [613.2024  530.21436]]
# [optimize][LBFGS] current loss = 35004.4023
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[686.39014 631.4943 ]
#  [613.07544 530.0484 ]
#  [613.1218  529.98737]]
# [optimize][LBFGS] current loss = 30230.4141
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[686.6245  630.91754]
#  [613.19727 529.3474 ]
#  [613.2435  529.28656]]
# [optimize][LBFGS] current loss = 22477.5469
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[683.94116 629.16174]
#  [610.3385  527.35486]
#  [610.3849  527.29407]]
# [optimize][LBFGS] current loss = 13964.7842
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[682.0281  627.9415 ]
#  [608.33154 525.99774]
#  [608.3778  525.937  ]]
# [optimize][LBFGS] current loss = 8687.9941
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[681.219   627.5648 ]
#  [607.5254  525.5973 ]
#  [607.57153 525.53644]]
# [optimize][LBFGS] current loss = 7706.6572
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[681.22815 627.6013 ]
#  [607.54004 525.64056]
#  [607.5864  525.5798 ]]
# [optimize][LBFGS] current loss = 7658.6597
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[681.23083 627.65234]
#  [607.54944 525.6987 ]
#  [607.5956  525.6381 ]]
# [optimize][LBFGS] current loss = 7508.5850
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[681.2008  627.77966]
#  [607.53174 525.83636]
#  [607.578   525.7758 ]]
# [optimize][LBFGS] current loss = 6901.8970
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[681.1129  627.8528 ]
#  [607.4408  525.89984]
#  [607.48694 525.83923]]
# [optimize][LBFGS] current loss = 6203.6064
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[680.7998  627.9271 ]
#  [607.0979  525.93567]
#  [607.1439  525.8751 ]]
# [optimize][LBFGS] current loss = 8572.4512
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[680.9564  627.80005]
#  [607.26074 525.80994]
#  [607.3069  525.74945]]
# [optimize][LBFGS] current loss = 5639.5767
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[680.93164 627.7558 ]
#  [607.2283  525.7562 ]
#  [607.2744  525.69574]]
# [optimize][LBFGS] current loss = 5570.3086
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[680.9054  627.70984]
#  [607.1947  525.69794]
#  [607.24084 525.63745]]
# [optimize][LBFGS] current loss = 5510.9253
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[680.86316 627.7167 ]
#  [607.1465  525.6994 ]
#  [607.1925  525.63904]]
# [optimize][LBFGS] current loss = 5467.2559
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[680.8496  627.7479 ]
#  [607.13293 525.724  ]
#  [607.17896 525.66364]]
# [optimize][LBFGS] current loss = 5387.4751
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[680.8065  627.8227 ]
#  [607.09766 525.8006 ]
#  [607.14355 525.74036]]
# [optimize][LBFGS] current loss = 5309.4443
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[680.84924 628.0428 ]
#  [607.14087 526.03784]
#  [607.18677 525.9775 ]]
# [optimize][LBFGS] current loss = 5274.9868
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[680.86597 627.97845]
#  [607.17017 525.9699 ]
#  [607.21606 525.90955]]
# [optimize][LBFGS] current loss = 5249.2490
# [rodrigues] input rvecs shape: torch.Size([1340, 3])
# [rodrigues] output R shape: torch.Size([1340, 3, 3])
# [forward] batch obs_uv shape: torch.Size([1340, 2]), pred_uv shape: torch.Size([1340, 2])
# [forward] sample obs_uv: [[675.1342  623.28357]
#  [601.7127  520.57666]
#  [601.7127  520.57666]], pred_uv: [[680.8573  627.97327]
#  [607.166   525.96405]
#  [607.21204 525.90375]]
# [optimize][LBFGS] current loss = 5223.7139
# [optimize] Completed optimization. cams_opt shape: (5, 6), points shape: (1282, 3)
#   局部 BA 完成，优化 5 台相机和 1282 个点
#   anchor 满 5，丢弃最早帧 4
# 注册帧 1：PnP 内点 382/444
#   新增 34 点，总共 1316 点
#   anchor 满 5，丢弃最早帧 6
# 注册帧 2：PnP 内点 1328/374
#   新增 0 点，总共 1316 点
#   anchor 满 5，丢弃最早帧 9
# 注册帧 5：PnP 内点 432/473
#   新增 0 点，总共 1316 点
#   anchor 满 5，丢弃最早帧 0
# 注册帧 8：PnP 内点 874/390
#   新增 22 点，总共 1338 点
#   anchor 满 5，丢弃最早帧 7
# 增量重建完成
# 相机数: 10, 三维点数: 1338

# %%
poses = sorted(camera_poses.keys())
sorted_pids = sorted(points_3d.keys())
points = np.vstack([points_3d[pid].reshape(1,3) for pid in sorted_pids])
print(f"Converted to points array of shape {points.shape}")

# 2. 构造 cams 列表
cams = []
for idx in poses:
    cam = camera_poses[idx]
    T = np.eye(4, dtype=np.float32)
    T[:3, :3] = cam['R']
    T[:3,  3] = cam['t'].reshape(3,)
    cams.append(T)
print(f"Built {len(cams)} camera poses as 4×4 matrices")
# Out:
# Converted to points array of shape (1338, 3)
# Built 10 camera poses as 4×4 matrices

# %% [markdown]
# ## Cell 6: Recentering and Camera Matrices

# %%
def recenter_poses_and_points(
    poses: List[Dict[str, Any]],
    points_3d: np.ndarray,
    world_filename: str,
    paths: List[str]
) -> Tuple[List[Dict[str, np.ndarray]], np.ndarray]:
    """
    对相机位姿和三维点做“重心化”处理：
    - world_filename 对应的那台相机 将成为新的原点且朝向不变
    - 其它相机与三维点 都按 R_w*(X - t_w) 变换到新坐标系

    Args:
        poses: List of {'R': (3,3), 't': (3,)}，原始世界坐标系下的相机外参
        points_3d: (N_pts,3) ndarray，原始世界坐标系下的三维点
        world_filename: 要作为新世界原点的那张图的文件名（例如 image_paths[0] 的 basename）
        paths:     List of 对应的所有图片完整路径

    Returns:
        new_poses: List of {'R': (3,3), 't': (3,)}，重心化后的相机外参
        new_points: (N_pts,3) ndarray，重心化后的三维点坐标
    """
    # 找到 world 相机在 poses/paths 中的索引
    idx_world = next(
        i for i, p in enumerate(paths)
        if os.path.basename(p) == world_filename
    )
    R_w = poses[idx_world]['R']
    t_w = poses[idx_world]['t'].reshape(3,)

    # 1) 重心化相机位姿
    new_poses = []
    for pose in poses:
        R_k = pose['R']
        t_k = pose['t'].reshape(3,)

        # 新的旋转、平移
        Rk_new = R_k @ R_w.T
        tk_new = t_k - (Rk_new @ t_w)

        new_poses.append({'R': Rk_new, 't': tk_new})

    # 2) 重心化三维点：X' = R_w @ (X - t_w)
    #    points_3d: (N_pts,3) → (3, N_pts) → 变换 → (N_pts,3)
    shifted = points_3d - t_w[None, :]        # (N_pts,3)
    new_points = (R_w @ shifted.T).T         # (N_pts,3)

    return new_poses, new_points

# %%
sorted_pids = sorted(points_3d.keys())
points = np.vstack([points_3d[pid].reshape(1,3) for pid in sorted_pids])
world_filename = "DJI_20200223_163225_243.jpg"
# 2. 把 camera_poses 转成和 image_paths 一一对应的列表
poses_list = []
valid_paths = []
for idx, path in enumerate(image_paths):
    cam = camera_poses.get(idx)
    if cam is None:
        continue
    R = cam['R']
    t = cam['t'].reshape(3,)    # 从 (3,1) → (3,)
    poses_list.append({'R': R, 't': t})
    valid_paths.append(path)

# 3. 调用 recenter_poses_and_points
new_poses_list, new_points = recenter_poses_and_points(
    poses_list,
    points,
    world_filename,
    valid_paths
)

# 4. 把 new_poses_list 再转回和 camera_poses 格式一致的 dict
new_camera_poses = {}
for idx, pose in enumerate(new_poses_list):
    new_camera_poses[idx] = {
        'R': pose['R'],
        't': pose['t'].reshape(3,1)   # 恢复成 (3,1)
    }


cams = []
for idx in sorted(new_camera_poses.keys()):
    cam = new_camera_poses[idx]
    T = np.eye(4, dtype=np.float32)
    T[:3,:3] = cam['R']
    T[:3, 3] = cam['t'].reshape(3,)
    cams.append(T)

# new_poses 是 [{'R':..., 't':...}, …]
# new_points 形状 (N_pts,3)

# %% [markdown]
# ## Cell 7: Bundle Adjustment

# %%
# 1) 按帧索引排序，构造相机齐次矩阵列表
sorted_cam_idxs = sorted(new_camera_poses.keys())
camera_matrices = []
for idx in sorted_cam_idxs:
    cam = new_camera_poses[idx]
    T = np.eye(4, dtype=np.float32)
    T[:3, :3] = cam['R']
    T[:3,  3] = cam['t'].reshape(3,)
    camera_matrices.append(T)
camera_matrices = np.stack(camera_matrices, axis=0)  # (N_cam,4,4)
print("相机矩阵形状:", camera_matrices.shape)

# 2) 把 points_3d 从 dict → (N_pt,3) ndarray
sorted_pt_ids = sorted(points_3d.keys())
ptid_to_idx = {pid:i for i,pid in enumerate(sorted_pt_ids)}
points_array = np.vstack([points_3d[pid].reshape(1,3) for pid in sorted_pt_ids])
points_array = points_array.astype(np.float32)       # (N_pt,3)
print("三维点数组形状:", points_array.shape)

# 3) 从 point_observations 拆出 obs_uv, camera_idxs, point_idxs
obs_uv      = []
camera_idxs = []
point_idxs  = []

for pid, cam_dict in point_observations.items():
    if pid not in ptid_to_idx:
        continue
    pt_idx = ptid_to_idx[pid]
    for cam_idx, uv in cam_dict.items():
        # 跳过那些未注册的相机
        if cam_idx not in new_camera_poses:
            continue
        # 把 cam_idx 转换到相机矩阵列表中的位置
        cam_list_idx = sorted_cam_idxs.index(cam_idx)
        obs_uv.append(uv)
        camera_idxs.append(cam_list_idx)
        point_idxs.append(pt_idx)

obs_uv      = np.array(obs_uv,      dtype=np.float32)  # (N_obs,2)
camera_idxs = np.array(camera_idxs, dtype=np.int64)    # (N_obs,)
point_idxs  = np.array(point_idxs,  dtype=np.int64)    # (N_obs,)
print("观测数量:", obs_uv.shape[0])
# Out:
# 相机矩阵形状: (10, 4, 4)
# 三维点数组形状: (1338, 3)
# 观测数量: 2676

# %%
# 4) 构造并运行 Bundle Adjustment
ba = TorchBundleAdjustment(
    camera_intrinsics=K, 
    init_cameras=camera_matrices,
    init_points=points_array
)
opt_cams, opt_pts, info = ba.optimize(
    cameras=camera_matrices,
    points_3d=points_3d,
    observations=obs_uv,
    point_indices=point_idxs,
    camera_indices=camera_idxs
)
# Out:
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[1914.6204  1893.8165 ]
#  [1843.9779  1517.1796 ]
#  [ 355.81845  511.8084 ]], pred_uv: [[1469.8751  2174.5103 ]
#  [1392.319   1786.4644 ]
#  [ 264.66968  775.28467]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[1953.6233  1131.9387 ]
#  [1417.1683  1011.24756]
#  [ 429.3999  1348.5549 ]], pred_uv: [[1474.291  1379.3684]
#  [1184.5869 1286.9719]
#  [-270.2351 1606.5372]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[2002.4377   1121.3077  ]
#  [1514.5957   1424.0057  ]
#  [ 103.747925 1929.5974  ]], pred_uv: [[1889.8636  1406.8062 ]
#  [1376.5673  1713.0546 ]
#  [-693.95264 2281.1199 ]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[2336.3752 1903.3877]
#  [1053.2137 1371.0393]
#  [2283.3445 1887.9601]], pred_uv: [[2386.7458  2189.4744 ]
#  [ 478.55554 1616.9927 ]
#  [1899.8851  2148.9907 ]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[1426.0353 1186.5464]
#  [1472.0684 1621.7952]
#  [1479.3546 1570.053 ]], pred_uv: [[1216.7318  1451.4984 ]
#  [ 979.39966 1878.9443 ]
#  [ 983.6405  1823.2195 ]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[ 461.89798 1354.3357 ]
#  [1875.0894  1083.4916 ]
#  [1851.1041  1633.8306 ]], pred_uv: [[-209.36108 1590.1395 ]
#  [1414.1597  1319.874  ]
#  [1413.9563  1884.7367 ]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[2432.094   657.0962]
#  [2069.9438 1246.1168]
#  [1200.6958 1356.6188]], pred_uv: [[2325.3833   955.5187 ]
#  [1629.4116  1481.9701 ]
#  [ 662.62695 1586.6726 ]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[2432.094   657.0962]
#  [2088.8467 1042.1675]
#  [2085.3481 1176.6068]], pred_uv: [[2330.872    950.89294]
#  [1972.8004  1309.1904 ]
#  [1972.9677  1438.0645 ]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[
]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[1484.0005  1119.3407 ]
#  [2951.3584  2279.4915 ]
#  [ 815.23987  547.85535]], pred_uv: [[1595.4744  1113.2222 ]
#  [3023.494   2319.5527 ]
#  [ 856.7623   749.52356]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[1653.5862 1364.2844]
#  [ 387.2592 1400.7534]
#  [1375.2423 1360.8165]], pred_uv: [[1499.2402  1361.6521 ]
#  [ 366.22107 1335.2449 ]
#  [1360.4836  1344.8889 ]]
# [rodrigues] input rvecs shape: torch.Size([116, 3])
# [rodrigues] output R shape: torch.Size([116, 3, 3])
# [forward] batch obs_uv shape: torch.Size([116, 2]), pred_uv shape: torch.Size([116, 2])
# [forward] sample obs_uv: [[2230.2888 1066.3043]
#  [ 585.8825 1103.4148]
#  [2275.1257  926.0741]], pred_uv: [[2235.4417  1098.0938 ]
#  [ 360.00073 1026.7476 ]
#  [2112.2395   967.8431 ]]
# [optimize][Adam] epoch 6/10, loss = 86847494.5000
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[2098.1648 1119.7089]
#  [2042.3655 1084.987 ]
#  [ 646.4798 1025.7742]], pred_uv: [[1928.0795  1144.2798 ]
#  [2218.1895  1116.8635 ]
#  [ 366.70813  941.2686 ]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[ 853.957  2355.487 ]
#  [2461.1162  734.7521]
#  [2194.786  1165.9271]], pred_uv: [[ 745.4988 2339.0237]
#  [2479.8616  791.7492]
#  [2196.2288 1192.4915]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# ...
#  [598.32947 406.53723]]
# [optimize][LBFGS] current loss = 16844822.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[735.54175 509.6269 ]
#  [607.213   637.8992 ]
#  [664.8063  406.85925]]
# [optimize][LBFGS] current loss = 10259542.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[731.5167  522.7359 ]
#  [591.9143  638.39435]
#  [659.9646  420.7074 ]]
# [optimize][LBFGS] current loss = 9795220.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[727.62463 536.4896 ]
#  [583.66345 633.95496]
#  [655.2883  435.22864]]
# [optimize][LBFGS] current loss = 9479636.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[724.885   545.61884]
#  [585.0244  627.16876]
#  [651.91296 444.9386 ]]
# [optimize][LBFGS] current loss = 9215013.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[722.8534  555.0757 ]
#  [600.58997 613.11084]
#  [649.02405 455.14917]]
# [optimize][LBFGS] current loss = 8768102.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[727.636   548.0311 ]
#  [612.2722  584.5036 ]
#  [653.5968  448.13818]]
# [optimize][LBFGS] current loss = 8846190.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[724.1671  551.28546]
#  [617.1837  601.5888 ]
#  [650.16174 451.38257]]
# [optimize][LBFGS] current loss = 8546170.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[724.64636 549.40063]
#  [618.88086 604.3917 ]
#  [650.7626  449.37805]]
# [optimize][LBFGS] current loss = 8516578.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[725.8319  545.50726]
#  [621.4885  608.53735]
#  [652.1743  445.25513]]
# [optimize][LBFGS] current loss = 8458404.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[726.8955  542.41595]
#  [622.3408  612.5389 ]
#  [653.4204  441.97644]]
# [optimize][LBFGS] current loss = 8380396.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[727.902   539.99194]
#  [620.2477  618.3604 ]
#  [654.5852  439.38342]]
# [optimize][LBFGS] current loss = 8226230.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[727.9531  539.5339 ]
#  [616.91223 623.61835]
#  [654.65515 438.8523 ]]
# [optimize][LBFGS] current loss = 7942142.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[725.2169  539.1527 ]
#  [612.26855 628.6429 ]
#  [651.85596 438.2312 ]]
# [optimize][LBFGS] current loss = 7564559.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[723.2167  543.8955 ]
#  [606.63477 630.8559 ]
#  [649.3523  443.26697]]
# [optimize][LBFGS] current loss = 6757175.5000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[720.9916  547.5789 ]
#  [607.5879  624.35394]
#  [646.7512  447.15613]]
# [optimize][LBFGS] current loss = 6239799.5000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[717.11255 549.48206]
#  [616.01465 614.28064]
#  [642.4214  449.15198]]
# [optimize][LBFGS] current loss = 5735071.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[718.5454  542.59784]
#  [624.7588  616.8479 ]
#  [644.1505  441.83008]]
# [optimize][LBFGS] current loss = 5519521.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[716.6621  541.25037]
#  [631.6389  616.3671 ]
#  [642.2001  440.4087 ]]
# [optimize][LBFGS] current loss = 5459721.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[717.36035 540.2181 ]
#  [633.5886  616.96344]
#  [642.9877  439.30457]]
# [optimize][LBFGS] current loss = 5430733.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[718.1721  538.9733 ]
#  [637.3417  618.27966]
#  [643.931   437.94177]]
# [optimize][LBFGS] current loss = 5337706.5000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[718.8684  538.8715 ]
#  [639.9785  619.2791 ]
#  [644.723   437.75317]]
# [optimize][LBFGS] current loss = 5195223.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[718.9928  540.24677]
#  [641.4728  620.09576]
#  [644.86646 439.0763 ]]
# [optimize][LBFGS] current loss = 4972570.5000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[716.93787 545.3366 ]
#  [640.61194 618.1362 ]
#  [642.7235  444.11438]]
# [optimize][LBFGS] current loss = 5435387.5000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[718.7217  543.98694]
#  [638.02844 619.7322 ]
#  [644.5012  442.8639 ]]
# [optimize][LBFGS] current loss = 4713161.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[718.3331  544.7125 ]
#  [636.31506 619.5205 ]
#  [644.05066 443.63892]]
# [optimize][LBFGS] current loss = 4663473.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[717.82336 546.3539 ]
#  [633.62866 619.1094 ]
#  [643.42847 445.36536]]
# [optimize][LBFGS] current loss = 4565023.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[717.51514 547.351  ]
#  [633.4358  619.2256 ]
#  [643.0642  446.38794]]
# [optimize][LBFGS] current loss = 4465073.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[717.7506  548.8386 ]
#  [636.6659  619.9435 ]
#  [643.2501  447.85864]]
# [optimize][LBFGS] current loss = 4168240.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[715.97815 550.7519 ]
#  [642.18396 622.93475]
#  [641.3728  449.65845]]
# [optimize][LBFGS] current loss = 3627253.5000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[742.444   542.7735 ]
#  [666.8501  613.82904]
#  [668.595   441.52625]]
# [optimize][LBFGS] current loss = 3708778.5000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[719.1549  548.8799 ]
#  [657.5995  625.59094]
#  [644.65576 447.52954]]
# [optimize][LBFGS] current loss = 3081877.5000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[719.40576 547.8559 ]
#  [657.63293 625.92426]
#  [644.9512  446.48425]]
# [optimize][LBFGS] current loss = 3036500.2500
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[720.1572 546.1386]
#  [659.4325 626.0886]
#  [645.7532 444.7157]]
# [optimize][LBFGS] current loss = 2999619.2500
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[720.8428  544.20325]
#  [661.2844  626.44073]
#  [646.4769  442.72754]]
# [optimize][LBFGS] current loss = 2960096.5000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[721.4469  540.60864]
#  [664.974   627.10046]
#  [647.0764  439.06067]]
# [optimize][LBFGS] current loss = 2871319.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[721.0244  536.34094]
#  [669.2229  628.2726 ]
#  [646.5304  434.75085]]
# [optimize][LBFGS] current loss = 2735415.0000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[718.1078  535.09467]
#  [671.9075  628.4996 ]
#  [643.2191  433.6587 ]]
# [optimize][LBFGS] current loss = 2581756.5000
# [rodrigues] input rvecs shape: torch.Size([2676, 3])
# [rodrigues] output R shape: torch.Size([2676, 3, 3])
# [forward] batch obs_uv shape: torch.Size([2676, 2]), pred_uv shape: torch.Size([2676, 2])
# [forward] sample obs_uv: [[727.6504  546.1891 ]
#  [675.1342  623.28357]
#  [652.8446  444.9021 ]], pred_uv: [[717.4249  533.9904 ]
#  [668.3943  632.2819 ]
#  [642.59155 432.5105 ]]
# [optimize][LBFGS] current loss = 2497828.0000
# [optimize] Completed optimization. cams_opt shape: (10, 6), points shape: (1338, 3)

# %% [markdown]
# ## Cell 8: Save Results

# %%
def save_outputs(points: np.ndarray, cameras: List[np.ndarray], output_dir: str):
    os.makedirs(output_dir, exist_ok=True)
    ply = os.path.join(output_dir, 'optimized_point_cloud.ply')
    with open(ply, 'w') as f:
        f.write('ply\nformat ascii 1.0\n')
        f.write(f'element vertex {points.shape[0]}\n')
        f.write('property float x\nproperty float y\nproperty float z\nend_header\n')
        for p in points:
            f.write(f"{p[0]} {p[1]} {p[2]}\n")
    traj = os.path.join(output_dir, 'optimized_camera_trajectory.txt')
    with open(traj, 'w') as f:
        f.write('# CamIdx tx ty tz qx qy qz qw\n')
        for i, T in enumerate(cameras):
            pos = T[:3,3]
            quat = R_scipy.from_matrix(T[:3,:3]).as_quat()
            f.write(f"{i} {pos[0]} {pos[1]} {pos[2]} {quat[0]} {quat[1]} {quat[2]} {quat[3]}\n")
    print(f"Saved PLY: {ply}\nSaved trajectory: {traj}")


def save_observation_data(
    obs_uv: np.ndarray,
    cam_idxs: np.ndarray,
    pt_idxs: np.ndarray,
    point_observations: dict,
    output_dir: str,
    basename: str = "observations"
):
    """
    Save sparse-SfM observation data to disk:
      - obs_uv, cam_idxs, pt_idxs as a compressed .npz
      - point_observations dict as a pickle
    """
    os.makedirs(output_dir, exist_ok=True)
    npz_path = os.path.join(output_dir, f"{basename}.npz")
    pkl_path = os.path.join(output_dir, f"{basename}.pkl")
    # Save arrays
    np.savez_compressed(npz_path, obs_uv=obs_uv, cam_idxs=cam_idxs, pt_idxs=pt_idxs)
    # Save dict
    with open(pkl_path, "wb") as f:
        pickle.dump(point_observations, f)
    print(f"Saved observation arrays to: {npz_path}")
    print(f"Saved observation dict to:   {pkl_path}")


# %%

# %%
#save_outputs(points, cams, OUTPUT_DIR)
save_outputs(opt_pts, opt_cams, OUTPUT_DIR)
save_observation_data(
    obs_uv,
    camera_idxs,
    point_idxs,
    point_observations,
    OUTPUT_DIR
)
# Out:
# Saved PLY: D:\lyz\Python\CV\AI4701\final project\ablation_output\optimized_point_cloud.ply
# Saved trajectory: D:\lyz\Python\CV\AI4701\final project\ablation_output\optimized_camera_trajectory.txt
# Saved observation arrays to: D:\lyz\Python\CV\AI4701\final project\ablation_output\observations.npz
# Saved observation dict to:   D:\lyz\Python\CV\AI4701\final project\ablation_output\observations.pkl

# %% [markdown]
# ## Cell 9: Visualization

# %%
pcd = o3d.io.read_point_cloud(os.path.join(OUTPUT_DIR, 'optimized_point_cloud.ply'))
points = np.asarray(pcd.points)
poses_vis = []
with open(os.path.join(OUTPUT_DIR, 'optimized_camera_trajectory.txt'), 'r') as f:
    for line in f:
        if line.startswith('#'): continue
        parts = line.split()
        _, tx, ty, tz, qx, qy, qz, qw = parts
        Rm = R_scipy.from_quat([float(qx),float(qy),float(qz),float(qw)]).as_matrix()
        poses_vis.append({'R': Rm, 't': np.array([float(tx),float(ty),float(tz)]).reshape(3,1)})

print(f"Loaded {len(points)} points and {len(poses_vis)} cameras.")
visualize_with_open3d(points, poses_vis,show_cameras=True)

camera_mats = []
for pose in poses_vis:
    T = np.eye(4, dtype=np.float64)
    T[:3,:3] = pose['R']
    T[:3, 3] = pose['t'].reshape(3)
    camera_mats.append(T)
camera_mats = np.stack(camera_mats, axis=0)  # → (N_cam,4,4)

visualize_colored_point_cloud(points, camera_mats ,valid_paths ,K)
# Out:
# Loaded 1338 points and 10 cameras.

# %% [markdown]
# ## Cell 10: Evaluation

# %%
def load_observation_data(
    npz_path: str,
    pkl_path: str
) -> tuple:
    """
    Load sparse-SfM observation data from disk.
    Returns: obs_uv, cam_idxs, pt_idxs, point_observations
    """
    # Load arrays
    data = np.load(npz_path)
    obs_uv = data["obs_uv"]
    cam_idxs = data["cam_idxs"]
    pt_idxs = data["pt_idxs"]
    # Load dict
    with open(pkl_path, "rb") as f:
        point_observations = pickle.load(f)
    print(f"Loaded observation arrays from: {npz_path}")
    print(f"Loaded observation dict from:   {pkl_path}")
    return obs_uv, cam_idxs, pt_idxs, point_observations

# %%
obs_uv2, cam_idxs2, pt_idxs2, point_observations2 = load_observation_data(
    os.path.join(OUTPUT_DIR, "observations.npz"),
    os.path.join(OUTPUT_DIR, "observations.pkl")
)

# 1) 计算重投影误差
errs = reprojection_errors(points, camera_mats, K, obs_uv2, cam_idxs2, pt_idxs2)
stats = reprojection_stats(errs)
print("Reproj error (px):", stats)

# 2) 点轨迹长度
track_stats = track_length_stats(point_observations)
print("Track lengths:", track_stats)

# 3) 图像覆盖度
cov_stats = image_coverage_stats(point_observations, camera_mats.shape[0])
print("Image coverage:", cov_stats)

# 4) 点/相机 比例
ratio = points_per_camera_ratio(points, camera_mats)
print("Points/Cameras:", ratio)
# Out:
# Loaded observation arrays from: D:\lyz\Python\CV\AI4701\final project\ablation_output\observations.npz
# Loaded observation dict from:   D:\lyz\Python\CV\AI4701\final project\ablation_output\observations.pkl
# Reproj error (px): {'mean': 13.810813964218728, 'median': 6.692110194140035, 'max': 361.3033171065232, 'std': 26.957382800252578}
# Track lengths: {'mean': 2.0, 'median': 2.0, 'max': 2, 'hist': array([   0,    0, 1338], dtype=int64)}
# Image coverage: {'per_image': array([  51,   34,    0, 1224,  792,    0,  503,    4,   22,   46]), 'mean': 267.6, 'median': 40.0, 'min': 0, 'max': 1224}
# Points/Cameras: 133.8
