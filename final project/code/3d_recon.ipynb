# %% [markdown]
# ## 导入所需的库文件

# %%
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import cv2
from typing import List, Dict, Any,Tuple
from scipy.spatial.transform import Rotation as R_scipy
import open3d as o3d
from contextlib import redirect_stdout
from feature_extraction import load_or_extract_features
from feature_matching import load_or_match_image_pairs, filter_two_view_geometry
from initial_recon import print_pose_info, pick_initial_pair
from pnp_recon import pnp_pose, visualize_with_open3d, triangulate_points,multi_view_triangulation,visualize_colored_point_cloud
from bundle_adjustment import BundleAdjustment,TorchBundleAdjustment
from metrics import reprojection_errors,reprojection_stats,track_length_stats,image_coverage_stats,points_per_camera_ratio
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# User parameters: adjust these paths before running
IMAGE_FOLDER = r"D:\lyz\Python\CV\AI4701\final project\images"
INTRINSICS_FILE = r"D:\lyz\Python\CV\AI4701\final project\camera_intrinsic.txt"
OUTPUT_DIR = r"D:\lyz\Python\CV\AI4701\final project\output"
SAVE_FEATURES = True
LOAD_FEATURES = False
VERBOSE = True

# %% [markdown]
# ## Cell 2: Load Images and Intrinsics

# %%
def load_images(image_folder: str) -> List[str]:
    paths = []
    for root, dirs, files in os.walk(image_folder):
        # 1. 只保留图片文件
        image_files = [
            f for f in files
            if f.lower().endswith(('.png', '.jpg', '.jpeg'))
        ]
        # 2. 按文件名逆序排序（"163225" > "163224"）
        image_files.sort(reverse=True)
        # 3. 拼接完整路径
        for f in image_files:
            paths.append(os.path.join(root, f))
    return paths


def load_intrinsics(k_path: str) -> np.ndarray:
    if not os.path.exists(k_path):
        raise FileNotFoundError(f"相机内参文件未找到：{k_path}")
    K = np.loadtxt(k_path, dtype=np.float32)
    if K.shape != (3, 3):
        raise ValueError(f"相机内参形状错误，应为3x3，但得到: {K.shape}")
    return K

# Load at module level
image_paths = load_images(IMAGE_FOLDER)
K = load_intrinsics(INTRINSICS_FILE)

# %% [markdown]
# ## Cell 3: Feature Extraction and Matching

# %%
def run_feature_pipeline(paths: List[str], K: np.ndarray, output_dir: str,
                         save: bool, load: bool, verbose: bool=True):
    def _run_quiet(func, *args, **kwargs):
        if verbose:
            return func(*args, **kwargs)
        with open(os.devnull, 'w') as devnull:
            with redirect_stdout(devnull):
                return func(*args, **kwargs)

    print("Extracting features...")
    features = _run_quiet(
        load_or_extract_features,
        paths, method='sift_improved', save=save, load=load, output_dir=output_dir
    )

    print("Matching features...")
    raw_matches = _run_quiet(
        load_or_match_image_pairs,
        features, method='sift', save=save, load=load, output_dir=output_dir
    )

    # RANSAC filtering
    n = len(features)
    al_matches = [[[] for _ in range(n)] for __ in range(n)]
    for i in range(n):
        for j in range(n):
            if i == j: continue
            kp1, _ = features[i]
            kp2, _ = features[j]
            m = raw_matches[i][j]
            if len(m) < 4:
                continue
            inliers, _ = _run_quiet(filter_two_view_geometry, kp1, kp2, m, K)
            # # 1) 从 m（List[cv2.DMatch]）里取坐标
            # pts1 = np.float32([ kp1[mi.queryIdx].pt for mi in m ])  # (N,2)
            # pts2 = np.float32([ kp2[mi.trainIdx].pt for mi in m ])  # (N,2)

            # # 2) 用 Essential 矩阵 + RANSAC 得到 mask
            # #    参数 threshold 可以根据你的像素精度调，比如 1.0–2.0 像素
            # E, mask = cv2.findEssentialMat(
            #     pts1, pts2, 
            #     cameraMatrix=K,
            #     method=cv2.RANSAC,
            #     prob=0.999,
            #     threshold=1.0
            # )
            # # mask 是一个 N×1 的 ndarray，值为 1 表示 inlier，0 表示 outlier

            # # 3) 根据 mask 筛出 inliers matches
            # inliers = [ m[i] for i in range(len(m)) if mask[i,0] == 1 ]

            # 4) 存回你的 al_matches
            al_matches[i][j] = inliers

    # Flatten into pairs
    matches_list = []
    for i in range(n):
        for j in range(i+1, n):
            if len(al_matches[i][j]) >= 4:
                matches_list.append((i, j, al_matches[i][j]))

    return features, al_matches, matches_list

# Execute
features, al_matches, matches_list = run_feature_pipeline(
    image_paths, K, OUTPUT_DIR, SAVE_FEATURES, LOAD_FEATURES, VERBOSE
)
# Out:
# Extracting features...
# 开始提取特征…
# 已保存所有图像特征到 D:\lyz\Python\CV\AI4701\final project\output\features.yml
# === 特征提取完成: 62/62 张图像有效 ===
# Matching features...
# [DEBUG] save=True，强制重新匹配并保存
#
# === [SIFT] 两两特征匹配开始 ===
# Matching features: 4858 vs 4490 descriptors
# Found 1467 good matches out of 4858 total matches
# Match ratio: 30.2%
# Distance stats - Min: 0.05, Max: 0.41, Mean: 0.19
# Matching features: 4858 vs 4199 descriptors
# Found 1018 good matches out of 4858 total matches
# Match ratio: 21.0%
# Distance stats - Min: 0.08, Max: 0.42, Mean: 0.21
# Matching features: 4858 vs 4486 descriptors
# Found 562 good matches out of 4858 total matches
# Match ratio: 11.6%
# Distance stats - Min: 0.11, Max: 0.42, Mean: 0.23
# Matching features: 4858 vs 4835 descriptors
# Found 451 good matches out of 4858 total matches
# Match ratio: 9.3%
# Distance stats - Min: 0.11, Max: 0.41, Mean: 0.24
# Matching features: 4858 vs 4578 descriptors
# Found 376 good matches out of 4858 total matches
# Match ratio: 7.7%
# Distance stats - Min: 0.10, Max: 0.37, Mean: 0.25
# Matching features: 4858 vs 4677 descriptors
# Found 259 good matches out of 4858 total matches
# Match ratio: 5.3%
# Distance stats - Min: 0.13, Max: 0.42, Mean: 0.25
# Matching features: 4858 vs 4977 descriptors
# Found 271 good matches out of 4858 total matches
# Match ratio: 5.6%
# Distance stats - Min: 0.10, Max: 0.39, Mean: 0.25
# Matching features: 4858 vs 4402 descriptors
# Found 445 good matches out of 4858 total matches
# Match ratio: 9.2%
# Distance stats - Min: 0.10, Max: 0.41, Mean: 0.24
# Matching features: 4858 vs 5041 descriptors
# Found 448 good matches out of 4858 total matches
# Match ratio: 9.2%
# Distance stats - Min: 0.10, Max: 0.46, Mean: 0.24
# Matching features: 4858 vs 4295 descriptors
# Found 685 good matches out of 4858 total matches
# Match ratio: 14.1%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.22
# Matching features: 4858 vs 4957 descriptors
# Found 886 good matches out of 4858 total matches
# Match ratio: 18.2%
# Distance stats - Min: 0.07, Max: 0.41, Mean: 0.21
# Matching features: 4858 vs 4838 descriptors
# Found 1255 good matches out of 4858 total matches
# Match ratio: 25.8%
# Distance stats - Min: 0.04, Max: 0.40, Mean: 0.20
# Matching features: 4858 vs 5006 descriptors
# Found 1240 good matches out of 4858 total matches
# Match ratio: 25.5%
# Distance stats - Min: 0.04, Max: 0.42, Mean: 0.20
# Matching features: 4858 vs 4929 descriptors
# Found 974 good matches out of 4858 total matches
# Match ratio: 20.0%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.21
# Matching features: 4858 vs 4784 descriptors
# Found 691 good matches out of 4858 total matches
# Match ratio: 14.2%
# Distance stats - Min: 0.09, Max: 0.43, Mean: 0.23
# Matching features: 4858 vs 4887 descriptors
# Found 670 good matches out of 4858 total matches
# Match ratio: 13.8%
# Distance stats - Min: 0.08, Max: 0.41, Mean: 0.22
# Matching features: 4858 vs 4640 descriptors
# Found 956 good matches out of 4858 total matches
# Match ratio: 19.7%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.20
# Matching features: 4858 vs 4929 descriptors
# Found 927 good matches out of 4858 total matches
# Match ratio: 19.1%
# Distance stats - Min: 0.07, Max: 0.39, Mean: 0.20
# Matching features: 4858 vs 4624 descriptors
# Found 845 good matches out of 4858 total matches
# Match ratio: 17.4%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.21
# Matching features: 4858 vs 4866 descriptors
# Found 680 good matches out of 4858 total matches
# Match ratio: 14.0%
# Distance stats - Min: 0.08, Max: 0.39, Mean: 0.22
# Matching features: 4858 vs 4692 descriptors
# Found 446 good matches out of 4858 total matches
# Match ratio: 9.2%
# Distance stats - Min: 0.10, Max: 0.39, Mean: 0.24
# Matching features: 4858 vs 4462 descriptors
# Found 494 good matches out of 4858 total matches
# Match ratio: 10.2%
# Distance stats - Min: 0.11, Max: 0.39, Mean: 0.24
# Matching features: 4858 vs 4293 descriptors
# Found 392 good matches out of 4858 total matches
# Match ratio: 8.1%
# Distance stats - Min: 0.12, Max: 0.40, Mean: 0.24
# Matching features: 4858 vs 4232 descriptors
# Found 359 good matches out of 4858 total matches
# Match ratio: 7.4%
# Distance stats - Min: 0.11, Max: 0.39, Mean: 0.25
# Matching features: 4858 vs 4534 descriptors
# Found 377 good matches out of 4858 total matches
# Match ratio: 7.8%
# Distance stats - Min: 0.12, Max: 0.43, Mean: 0.25
# Matching features: 4858 vs 4377 descriptors
# Found 421 good matches out of 4858 total matches
# Match ratio: 8.7%
# Distance stats - Min: 0.11, Max: 0.41, Mean: 0.24
# Matching features: 4858 vs 4844 descriptors
# Found 376 good matches out of 4858 total matches
# Match ratio: 7.7%
# Distance stats - Min: 0.12, Max: 0.39, Mean: 0.24
# Matching features: 4858 vs 4875 descriptors
# Found 417 good matches out of 4858 total matches
# Match ratio: 8.6%
# Distance stats - Min: 0.09, Max: 0.40, Mean: 0.23
# Matching features: 4858 vs 5235 descriptors
# Found 537 good matches out of 4858 total matches
# Match ratio: 11.1%
# Distance stats - Min: 0.09, Max: 0.40, Mean: 0.23
# Matching features: 4858 vs 4745 descriptors
# Found 738 good matches out of 4858 total matches
# Match ratio: 15.2%
# Distance stats - Min: 0.06, Max: 0.40, Mean: 0.22
# Matching features: 4858 vs 4777 descriptors
# Found 776 good matches out of 4858 total matches
# Match ratio: 16.0%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.22
# Matching features: 4858 vs 4941 descriptors
# Found 636 good matches out of 4858 total matches
# Match ratio: 13.1%
# Distance stats - Min: 0.10, Max: 0.42, Mean: 0.23
# Matching features: 4858 vs 4985 descriptors
# Found 481 good matches out of 4858 total matches
# Match ratio: 9.9%
# Distance stats - Min: 0.10, Max: 0.41, Mean: 0.24
# Matching features: 4858 vs 5192 descriptors
# Found 477 good matches out of 4858 total matches
# Match ratio: 9.8%
# Distance stats - Min: 0.10, Max: 0.42, Mean: 0.24
# Matching features: 4858 vs 4925 descriptors
# Found 735 good matches out of 4858 total matches
# Match ratio: 15.1%
# Distance stats - Min: 0.09, Max: 0.39, Mean: 0.23
# Matching features: 4858 vs 4762 descriptors
# Found 661 good matches out of 4858 total matches
# Match ratio: 13.6%
# Distance stats - Min: 0.09, Max: 0.37, Mean: 0.23
# Matching features: 4858 vs 4617 descriptors
# Found 566 good matches out of 4858 total matches
# Match ratio: 11.7%
# Distance stats - Min: 0.10, Max: 0.40, Mean: 0.23
# Matching features: 4858 vs 4564 descriptors
# Found 499 good matches out of 4858 total matches
# Match ratio: 10.3%
# Distance stats - Min: 0.09, Max: 0.39, Mean: 0.24
# Matching features: 4858 vs 4324 descriptors
# Found 484 good matches out of 4858 total matches
# Match ratio: 10.0%
# Distance stats - Min: 0.10, Max: 0.45, Mean: 0.24
# Matching features: 4858 vs 4498 descriptors
# Found 438 good matches out of 4858 total matches
# Match ratio: 9.0%
# Distance stats - Min: 0.11, Max: 0.37, Mean: 0.24
# Matching features: 4858 vs 4798 descriptors
# Found 394 good matches out of 4858 total matches
# Match ratio: 8.1%
# Distance stats - Min: 0.12, Max: 0.39, Mean: 0.25
# Matching features: 4858 vs 4021 descriptors
# Found 352 good matches out of 4858 total matches
# Match ratio: 7.2%
# Distance stats - Min: 0.11, Max: 0.40, Mean: 0.25
# Matching features: 4858 vs 4327 descriptors
# Found 300 good matches out of 4858 total matches
# Match ratio: 6.2%
# Distance stats - Min: 0.12, Max: 0.39, Mean: 0.26
# Matching features: 4858 vs 4813 descriptors
# Found 296 good matches out of 4858 total matches
# Match ratio: 6.1%
# Distance stats - Min: 0.13, Max: 0.42, Mean: 0.26
# Matching features: 4858 vs 4483 descriptors
# Found 332 good matches out of 4858 total matches
# Match ratio: 6.8%
# Distance stats - Min: 0.10, Max: 0.40, Mean: 0.25
# Matching features: 4858 vs 4460 descriptors
# Found 351 good matches out of 4858 total matches
# Match ratio: 7.2%
# Distance stats - Min: 0.10, Max: 0.40, Mean: 0.25
# Matching features: 4858 vs 4537 descriptors
# Found 388 good matches out of 4858 total matches
# Match ratio: 8.0%
# Distance stats - Min: 0.13, Max: 0.39, Mean: 0.24
# Matching features: 4858 vs 4610 descriptors
# Found 457 good matches out of 4858 total matches
# Match ratio: 9.4%
# Distance stats - Min: 0.12, Max: 0.39, Mean: 0.24
# Matching features: 4858 vs 4560 descriptors
# Found 475 good matches out of 4858 total matches
# Match ratio: 9.8%
# Distance stats - Min: 0.09, Max: 0.41, Mean: 0.24
# Matching features: 4858 vs 4816 descriptors
# Found 528 good matches out of 4858 total matches
# Match ratio: 10.9%
# Distance stats - Min: 0.11, Max: 0.42, Mean: 0.24
# Matching features: 4858 vs 4342 descriptors
# Found 491 good matches out of 4858 total matches
# Match ratio: 10.1%
# Distance stats - Min: 0.10, Max: 0.38, Mean: 0.24
# Matching features: 4858 vs 4782 descriptors
# Found 342 good matches out of 4858 total matches
# Match ratio: 7.0%
# Distance stats - Min: 0.12, Max: 0.41, Mean: 0.25
# Matching features: 4858 vs 4795 descriptors
# Found 380 good matches out of 4858 total matches
# Match ratio: 7.8%
# Distance stats - Min: 0.14, Max: 0.38, Mean: 0.25
# Matching features: 4858 vs 4980 descriptors
# Found 309 good matches out of 4858 total matches
# Match ratio: 6.4%
# Distance stats - Min: 0.12, Max: 0.40, Mean: 0.25
# Matching features: 4858 vs 4942 descriptors
# Found 340 good matches out of 4858 total matches
# Match ratio: 7.0%
# Distance stats - Min: 0.12, Max: 0.40, Mean: 0.26
# Matching features: 4858 vs 4621 descriptors
# Found 374 good matches out of 4858 total matches
# Match ratio: 7.7%
# Distance stats - Min: 0.12, Max: 0.41, Mean: 0.25
# Matching features: 4858 vs 4438 descriptors
# Found 334 good matches out of 4858 total matches
# Match ratio: 6.9%
# Distance stats - Min: 0.12, Max: 0.41, Mean: 0.25
# Matching features: 4858 vs 4425 descriptors
# Found 313 good matches out of 4858 total matches
# Match ratio: 6.4%
# Distance stats - Min: 0.12, Max: 0.39, Mean: 0.25
# Matching features: 4858 vs 4712 descriptors
# Found 258 good matches out of 4858 total matches
# Match ratio: 5.3%
# Distance stats - Min: 0.14, Max: 0.41, Mean: 0.26
# Matching features: 4858 vs 4903 descriptors
# Found 282 good matches out of 4858 total matches
# Match ratio: 5.8%
# Distance stats - Min: 0.15, Max: 0.40, Mean: 0.26
# Matching features: 4858 vs 4197 descriptors
# Found 223 good matches out of 4858 total matches
# Match ratio: 4.6%
# Distance stats - Min: 0.14, Max: 0.41, Mean: 0.26
# Matching features: 4490 vs 4858 descriptors
# Found 1461 good matches out of 4490 total matches
# Match ratio: 32.5%
# Distance stats - Min: 0.05, Max: 0.38, Mean: 0.19
# Matching features: 4490 vs 4199 descriptors
# Found 1542 good matches out of 4490 total matches
# Match ratio: 34.3%
# Distance stats - Min: 0.06, Max: 0.40, Mean: 0.19
# Matching features: 4490 vs 4486 descriptors
# Found 740 good matches out of 4490 total matches
# Match ratio: 16.5%
# Distance stats - Min: 0.07, Max: 0.39, Mean: 0.22
# Matching features: 4490 vs 4835 descriptors
# Found 546 good matches out of 4490 total matches
# Match ratio: 12.2%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.23
# Matching features: 4490 vs 4578 descriptors
# Found 497 good matches out of 4490 total matches
# Match ratio: 11.1%
# Distance stats - Min: 0.10, Max: 0.40, Mean: 0.24
# Matching features: 4490 vs 4677 descriptors
# Found 353 good matches out of 4490 total matches
# Match ratio: 7.9%
# Distance stats - Min: 0.12, Max: 0.40, Mean: 0.25
# Matching features: 4490 vs 4977 descriptors
# Found 369 good matches out of 4490 total matches
# Match ratio: 8.2%
# Distance stats - Min: 0.11, Max: 0.41, Mean: 0.24
# Matching features: 4490 vs 4402 descriptors
# Found 555 good matches out of 4490 total matches
# Match ratio: 12.4%
# Distance stats - Min: 0.10, Max: 0.39, Mean: 0.23
# Matching features: 4490 vs 5041 descriptors
# Found 572 good matches out of 4490 total matches
# Match ratio: 12.7%
# Distance stats - Min: 0.08, Max: 0.41, Mean: 0.23
# Matching features: 4490 vs 4295 descriptors
# Found 921 good matches out of 4490 total matches
# Match ratio: 20.5%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.21
# Matching features: 4490 vs 4957 descriptors
# Found 1126 good matches out of 4490 total matches
# Match ratio: 25.1%
# Distance stats - Min: 0.05, Max: 0.40, Mean: 0.20
# Matching features: 4490 vs 4838 descriptors
# Found 1144 good matches out of 4490 total matches
# Match ratio: 25.5%
# Distance stats - Min: 0.05, Max: 0.41, Mean: 0.20
# Matching features: 4490 vs 5006 descriptors
# Found 826 good matches out of 4490 total matches
# Match ratio: 18.4%
# Distance stats - Min: 0.08, Max: 0.45, Mean: 0.22
# Matching features: 4490 vs 4929 descriptors
# Found 707 good matches out of 4490 total matches
# Match ratio: 15.7%
# Distance stats - Min: 0.09, Max: 0.40, Mean: 0.23
# Matching features: 4490 vs 4784 descriptors
# Found 508 good matches out of 4490 total matches
# Match ratio: 11.3%
# Distance stats - Min: 0.10, Max: 0.43, Mean: 0.24
# Matching features: 4490 vs 4887 descriptors
# Found 506 good matches out of 4490 total matches
# Match ratio: 11.3%
# Distance stats - Min: 0.09, Max: 0.40, Mean: 0.23
# Matching features: 4490 vs 4640 descriptors
# Found 764 good matches out of 4490 total matches
# Match ratio: 17.0%
# Distance stats - Min: 0.07, Max: 0.37, Mean: 0.21
# Matching features: 4490 vs 4929 descriptors
# Found 796 good matches out of 4490 total matches
# Match ratio: 17.7%
# Distance stats - Min: 0.07, Max: 0.36, Mean: 0.21
# Matching features: 4490 vs 4624 descriptors
# Found 999 good matches out of 4490 total matches
# Match ratio: 22.2%
# Distance stats - Min: 0.06, Max: 0.39, Mean: 0.20
# Matching features: 4490 vs 4866 descriptors
# Found 799 good matches out of 4490 total matches
# Match ratio: 17.8%
# Distance stats - Min: 0.08, Max: 0.39, Mean: 0.21
# Matching features: 4490 vs 4692 descriptors
# Found 608 good matches out of 4490 total matches
# Match ratio: 13.5%
# Distance stats - Min: 0.07, Max: 0.39, Mean: 0.22
# Matching features: 4490 vs 4462 descriptors
# Found 609 good matches out of 4490 total matches
# Match ratio: 13.6%
# Distance stats - Min: 0.10, Max: 0.40, Mean: 0.23
# Matching features: 4490 vs 4293 descriptors
# Found 508 good matches out of 4490 total matches
# Match ratio: 11.3%
# Distance stats - Min: 0.09, Max: 0.39, Mean: 0.23
# Matching features: 4490 vs 4232 descriptors
# Found 450 good matches out of 4490 total matches
# Match ratio: 10.0%
# Distance stats - Min: 0.11, Max: 0.41, Mean: 0.24
# Matching features: 4490 vs 4534 descriptors
# Found 491 good matches out of 4490 total matches
# Match ratio: 10.9%
# Distance stats - Min: 0.11, Max: 0.40, Mean: 0.24
# Matching features: 4490 vs 4377 descriptors
# Found 559 good matches out of 4490 total matches
# Match ratio: 12.4%
# Distance stats - Min: 0.07, Max: 0.38, Mean: 0.23
# Matching features: 4490 vs 4844 descriptors
# Found 520 good matches out of 4490 total matches
# Match ratio: 11.6%
# Distance stats - Min: 0.09, Max: 0.42, Mean: 0.24
# Matching features: 4490 vs 4875 descriptors
# Found 561 good matches out of 4490 total matches
# Match ratio: 12.5%
# Distance stats - Min: 0.09, Max: 0.38, Mean: 0.23
# Matching features: 4490 vs 5235 descriptors
# Found 655 good matches out of 4490 total matches
# Match ratio: 14.6%
# Distance stats - Min: 0.07, Max: 0.39, Mean: 0.23
# Matching features: 4490 vs 4745 descriptors
# Found 719 good matches out of 4490 total matches
# Match ratio: 16.0%
# Distance stats - Min: 0.09, Max: 0.42, Mean: 0.22
# Matching features: 4490 vs 4777 descriptors
# Found 662 good matches out of 4490 total matches
# Match ratio: 14.7%
# Distance stats - Min: 0.10, Max: 0.39, Mean: 0.22
# Matching features: 4490 vs 4941 descriptors
# Found 446 good matches out of 4490 total matches
# Match ratio: 9.9%
# Distance stats - Min: 0.11, Max: 0.40, Mean: 0.24
# Matching features: 4490 vs 4985 descriptors
# Found 373 good matches out of 4490 total matches
# Match ratio: 8.3%
# Distance stats - Min: 0.09, Max: 0.38, Mean: 0.25
# Matching features: 4490 vs 5192 descriptors
# Found 344 good matches out of 4490 total matches
# Match ratio: 7.7%
# Distance stats - Min: 0.10, Max: 0.38, Mean: 0.25
# Matching features: 4490 vs 4925 descriptors
# Found 576 good matches out of 4490 total matches
# Match ratio: 12.8%
# Distance stats - Min: 0.10, Max: 0.41, Mean: 0.23
# Matching features: 4490 vs 4762 descriptors
# Found 645 good matches out of 4490 total matches
# Match ratio: 14.4%
# Distance stats - Min: 0.08, Max: 0.39, Mean: 0.23
# Matching features: 4490 vs 4617 descriptors
# Found 615 good matches out of 4490 total matches
# Match ratio: 13.7%
# Distance stats - Min: 0.07, Max: 0.41, Mean: 0.23
# Matching features: 4490 vs 4564 descriptors
# Found 575 good matches out of 4490 total matches
# Match ratio: 12.8%
# Distance stats - Min: 0.09, Max: 0.40, Mean: 0.23
# Matching features: 4490 vs 4324 descriptors
# Found 622 good matches out of 4490 total matches
# Match ratio: 13.9%
# Distance stats - Min: 0.08, Max: 0.41, Mean: 0.23
# Matching features: 4490 vs 4498 descriptors
# Found 566 good matches out of 4490 total matches
# Match ratio: 12.6%
# Distance stats - Min: 0.10, Max: 0.41, Mean: 0.23
# Matching features: 4490 vs 4798 descriptors
# Found 475 good matches out of 4490 total matches
# Match ratio: 10.6%
# Distance stats - Min: 0.11, Max: 0.39, Mean: 0.24
# Matching features: 4490 vs 4021 descriptors
# Found 438 good matches out of 4490 total matches
# Match ratio: 9.8%
# Distance stats - Min: 0.11, Max: 0.39, Mean: 0.24
# Matching features: 4490 vs 4327 descriptors
# Found 411 good matches out of 4490 total matches
# Match ratio: 9.2%
# Distance stats - Min: 0.12, Max: 0.39, Mean: 0.25
# Matching features: 4490 vs 4813 descriptors
# Found 376 good matches out of 4490 total matches
# Match ratio: 8.4%
# Distance stats - Min: 0.12, Max: 0.41, Mean: 0.25
# Matching features: 4490 vs 4483 descriptors
# Found 432 good matches out of 4490 total matches
# Match ratio: 9.6%
# Distance stats - Min: 0.13, Max: 0.41, Mean: 0.25
# Matching features: 4490 vs 4460 descriptors
# Found 456 good matches out of 4490 total matches
# Match ratio: 10.2%
# Distance stats - Min: 0.12, Max: 0.39, Mean: 0.24
# Matching features: 4490 vs 4537 descriptors
# Found 490 good matches out of 4490 total matches
# Match ratio: 10.9%
# Distance stats - Min: 0.09, Max: 0.39, Mean: 0.24
# Matching features: 4490 vs 4610 descriptors
# Found 505 good matches out of 4490 total matches
# Match ratio: 11.2%
# Distance stats - Min: 0.09, Max: 0.39, Mean: 0.24
# Matching features: 4490 vs 4560 descriptors
# Found 540 good matches out of 4490 total matches
# Match ratio: 12.0%
# Distance stats - Min: 0.11, Max: 0.38, Mean: 0.23
# Matching features: 4490 vs 4816 descriptors
# Found 507 good matches out of 4490 total matches
# Match ratio: 11.3%
# Distance stats - Min: 0.10, Max: 0.38, Mean: 0.24
# Matching features: 4490 vs 4342 descriptors
# Found 517 good matches out of 4490 total matches
# Match ratio: 11.5%
# Distance stats - Min: 0.11, Max: 0.41, Mean: 0.24
# Matching features: 4490 vs 4782 descriptors
# Found 279 good matches out of 4490 total matches
# Match ratio: 6.2%
# Distance stats - Min: 0.15, Max: 0.44, Mean: 0.26
# Matching features: 4490 vs 4795 descriptors
# Found 286 good matches out of 4490 total matches
# Match ratio: 6.4%
# Distance stats - Min: 0.12, Max: 0.37, Mean: 0.25
# Matching features: 4490 vs 4980 descriptors
# Found 289 good matches out of 4490 total matches
# Match ratio: 6.4%
# Distance stats - Min: 0.13, Max: 0.42, Mean: 0.26
# Matching features: 4490 vs 4942 descriptors
# Found 307 good matches out of 4490 total matches
# Match ratio: 6.8%
# Distance stats - Min: 0.13, Max: 0.42, Mean: 0.25
# Matching features: 4490 vs 4621 descriptors
# Found 352 good matches out of 4490 total matches
# Match ratio: 7.8%
# Distance stats - Min: 0.12, Max: 0.40, Mean: 0.24
# Matching features: 4490 vs 4438 descriptors
# Found 399 good matches out of 4490 total matches
# Match ratio: 8.9%
# Distance stats - Min: 0.12, Max: 0.40, Mean: 0.25
# Matching features: 4490 vs 4425 descriptors
# Found 376 good matches out of 4490 total matches
# Match ratio: 8.4%
# Distance stats - Min: 0.12, Max: 0.43, Mean: 0.25
# Matching features: 4490 vs 4712 descriptors
# Found 303 good matches out of 4490 total matches
# Match ratio: 6.7%
# Distance stats - Min: 0.11, Max: 0.41, Mean: 0.26
# Matching features: 4490 vs 4903 descriptors
# Found 322 good matches out of 4490 total matches
# Match ratio: 7.2%
# Distance stats - Min: 0.13, Max: 0.38, Mean: 0.26
# Matching features: 4490 vs 4197 descriptors
# Found 296 good matches out of 4490 total matches
# Match ratio: 6.6%
# Distance stats - Min: 0.12, Max: 0.39, Mean: 0.26
# Matching features: 4199 vs 4858 descriptors
# Found 1015 good matches out of 4199 total matches
# Match ratio: 24.2%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.21
# Matching features: 4199 vs 4490 descriptors
# Found 1521 good matches out of 4199 total matches
# Match ratio: 36.2%
# Distance stats - Min: 0.06, Max: 0.42, Mean: 0.19
# Matching features: 4199 vs 4486 descriptors
# Found 1009 good matches out of 4199 total matches
# Match ratio: 24.0%
# Distance stats - Min: 0.07, Max: 0.41, Mean: 0.20
# Matching features: 4199 vs 4835 descriptors
# Found 723 good matches out of 4199 total matches
# Match ratio: 17.2%
# Distance stats - Min: 0.07, Max: 0.39, Mean: 0.22
# Matching features: 4199 vs 4578 descriptors
# Found 622 good matches out of 4199 total matches
# Match ratio: 14.8%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.23
# Matching features: 4199 vs 4677 descriptors
# Found 456 good matches out of 4199 total matches
# Match ratio: 10.9%
# Distance stats - Min: 0.09, Max: 0.42, Mean: 0.23
# Matching features: 4199 vs 4977 descriptors
# Found 490 good matches out of 4199 total matches
# Match ratio: 11.7%
# Distance stats - Min: 0.08, Max: 0.41, Mean: 0.23
# Matching features: 4199 vs 4402 descriptors
# Found 723 good matches out of 4199 total matches
# Match ratio: 17.2%
# Distance stats - Min: 0.08, Max: 0.42, Mean: 0.21
# Matching features: 4199 vs 5041 descriptors
# Found 712 good matches out of 4199 total matches
# Match ratio: 17.0%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.22
# Matching features: 4199 vs 4295 descriptors
# Found 1133 good matches out of 4199 total matches
# Match ratio: 27.0%
# Distance stats - Min: 0.04, Max: 0.39, Mean: 0.19
# Matching features: 4199 vs 4957 descriptors
# Found 1054 good matches out of 4199 total matches
# Match ratio: 25.1%
# Distance stats - Min: 0.04, Max: 0.40, Mean: 0.20
# Matching features: 4199 vs 4838 descriptors
# Found 827 good matches out of 4199 total matches
# Match ratio: 19.7%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.22
# Matching features: 4199 vs 5006 descriptors
# Found 583 good matches out of 4199 total matches
# Match ratio: 13.9%
# Distance stats - Min: 0.11, Max: 0.40, Mean: 0.24
# Matching features: 4199 vs 4929 descriptors
# Found 494 good matches out of 4199 total matches
# Match ratio: 11.8%
# Distance stats - Min: 0.13, Max: 0.40, Mean: 0.25
# Matching features: 4199 vs 4784 descriptors
# Found 350 good matches out of 4199 total matches
# Match ratio: 8.3%
# Distance stats - Min: 0.13, Max: 0.43, Mean: 0.25
# Matching features: 4199 vs 4887 descriptors
# Found 378 good matches out of 4199 total matches
# Match ratio: 9.0%
# Distance stats - Min: 0.11, Max: 0.39, Mean: 0.24
# Matching features: 4199 vs 4640 descriptors
# Found 569 good matches out of 4199 total matches
# Match ratio: 13.6%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.22
# Matching features: 4199 vs 4929 descriptors
# Found 635 good matches out of 4199 total matches
# Match ratio: 15.1%
# Distance stats - Min: 0.10, Max: 0.39, Mean: 0.23
# Matching features: 4199 vs 4624 descriptors
# Found 842 good matches out of 4199 total matches
# Match ratio: 20.1%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.21
# Matching features: 4199 vs 4866 descriptors
# Found 846 good matches out of 4199 total matches
# Match ratio: 20.1%
# Distance stats - Min: 0.06, Max: 0.37, Mean: 0.21
# Matching features: 4199 vs 4692 descriptors
# Found 712 good matches out of 4199 total matches
# Match ratio: 17.0%
# Distance stats - Min: 0.06, Max: 0.41, Mean: 0.21
# Matching features: 4199 vs 4462 descriptors
# Found 775 good matches out of 4199 total matches
# Match ratio: 18.5%
# Distance stats - Min: 0.07, Max: 0.42, Mean: 0.21
# Matching features: 4199 vs 4293 descriptors
# Found 644 good matches out of 4199 total matches
# Match ratio: 15.3%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.22
# Matching features: 4199 vs 4232 descriptors
# Found 547 good matches out of 4199 total matches
# Match ratio: 13.0%
# Distance stats - Min: 0.08, Max: 0.42, Mean: 0.23
# Matching features: 4199 vs 4534 descriptors
# Found 588 good matches out of 4199 total matches
# Match ratio: 14.0%
# Distance stats - Min: 0.09, Max: 0.44, Mean: 0.23
# Matching features: 4199 vs 4377 descriptors
# Found 650 good matches out of 4199 total matches
# Match ratio: 15.5%
# Distance stats - Min: 0.09, Max: 0.42, Mean: 0.21
# Matching features: 4199 vs 4844 descriptors
# Found 602 good matches out of 4199 total matches
# Match ratio: 14.3%
# Distance stats - Min: 0.09, Max: 0.42, Mean: 0.23
# Matching features: 4199 vs 4875 descriptors
# Found 639 good matches out of 4199 total matches
# Match ratio: 15.2%
# Distance stats - Min: 0.08, Max: 0.41, Mean: 0.22
# Matching features: 4199 vs 5235 descriptors
# Found 597 good matches out of 4199 total matches
# Match ratio: 14.2%
# Distance stats - Min: 0.07, Max: 0.39, Mean: 0.23
# Matching features: 4199 vs 4745 descriptors
# Found 567 good matches out of 4199 total matches
# Match ratio: 13.5%
# Distance stats - Min: 0.11, Max: 0.38, Mean: 0.23
# Matching features: 4199 vs 4777 descriptors
# Found 486 good matches out of 4199 total matches
# Match ratio: 11.6%
# Distance stats - Min: 0.09, Max: 0.40, Mean: 0.23
# Matching features: 4199 vs 4941 descriptors
# Found 328 good matches out of 4199 total matches
# Match ratio: 7.8%
# Distance stats - Min: 0.12, Max: 0.39, Mean: 0.25
# Matching features: 4199 vs 4985 descriptors
# Found 276 good matches out of 4199 total matches
# Match ratio: 6.6%
# Distance stats - Min: 0.12, Max: 0.39, Mean: 0.26
# Matching features: 4199 vs 5192 descriptors
# Found 264 good matches out of 4199 total matches
# Match ratio: 6.3%
# Distance stats - Min: 0.13, Max: 0.39, Mean: 0.26
# Matching features: 4199 vs 4925 descriptors
# Found 477 good matches out of 4199 total matches
# Match ratio: 11.4%
# Distance stats - Min: 0.11, Max: 0.39, Mean: 0.23
# Matching features: 4199 vs 4762 descriptors
# Found 592 good matches out of 4199 total matches
# Match ratio: 14.1%
# Distance stats - Min: 0.09, Max: 0.40, Mean: 0.23
# Matching features: 4199 vs 4617 descriptors
# Found 619 good matches out of 4199 total matches
# Match ratio: 14.7%
# Distance stats - Min: 0.09, Max: 0.41, Mean: 0.23
# Matching features: 4199 vs 4564 descriptors
# Found 631 good matches out of 4199 total matches
# Match ratio: 15.0%
# Distance stats - Min: 0.08, Max: 0.39, Mean: 0.23
# Matching features: 4199 vs 4324 descriptors
# Found 708 good matches out of 4199 total matches
# Match ratio: 16.9%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.22
# Matching features: 4199 vs 4498 descriptors
# Found 633 good matches out of 4199 total matches
# Match ratio: 15.1%
# Distance stats - Min: 0.08, Max: 0.38, Mean: 0.22
# Matching features: 4199 vs 4798 descriptors
# Found 580 good matches out of 4199 total matches
# Match ratio: 13.8%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.24
# Matching features: 4199 vs 4021 descriptors
# Found 549 good matches out of 4199 total matches
# Match ratio: 13.1%
# Distance stats - Min: 0.09, Max: 0.42, Mean: 0.23
# Matching features: 4199 vs 4327 descriptors
# Found 532 good matches out of 4199 total matches
# Match ratio: 12.7%
# Distance stats - Min: 0.10, Max: 0.40, Mean: 0.24
# Matching features: 4199 vs 4813 descriptors
# Found 419 good matches out of 4199 total matches
# Match ratio: 10.0%
# Distance stats - Min: 0.12, Max: 0.45, Mean: 0.24
# Matching features: 4199 vs 4483 descriptors
# Found 516 good matches out of 4199 total matches
# Match ratio: 12.3%
# Distance stats - Min: 0.10, Max: 0.41, Mean: 0.24
# Matching features: 4199 vs 4460 descriptors
# Found 504 good matches out of 4199 total matches
# Match ratio: 12.0%
# Distance stats - Min: 0.09, Max: 0.41, Mean: 0.24
# Matching features: 4199 vs 4537 descriptors
# Found 548 good matches out of 4199 total matches
# Match ratio: 13.1%
# Distance stats - Min: 0.11, Max: 0.39, Mean: 0.23
# Matching features: 4199 vs 4610 descriptors
# Found 520 good matches out of 4199 total matches
# Match ratio: 12.4%
# Distance stats - Min: 0.10, Max: 0.38, Mean: 0.23
# Matching features: 4199 vs 4560 descriptors
# Found 540 good matches out of 4199 total matches
# Match ratio: 12.9%
# Distance stats - Min: 0.10, Max: 0.39, Mean: 0.24
# Matching features: 4199 vs 4816 descriptors
# Found 459 good matches out of 4199 total matches
# Match ratio: 10.9%
# Distance stats - Min: 0.12, Max: 0.42, Mean: 0.24
# Matching features: 4199 vs 4342 descriptors
# Found 448 good matches out of 4199 total matches
# Match ratio: 10.7%
# Distance stats - Min: 0.10, Max: 0.40, Mean: 0.24
# Matching features: 4199 vs 4782 descriptors
# Found 214 good matches out of 4199 total matches
# Match ratio: 5.1%
# Distance stats - Min: 0.14, Max: 0.39, Mean: 0.26
# Matching features: 4199 vs 4795 descriptors
# Found 258 good matches out of 4199 total matches
# Match ratio: 6.1%
# Distance stats - Min: 0.15, Max: 0.37, Mean: 0.26
# Matching features: 4199 vs 4980 descriptors
# Found 252 good matches out of 4199 total matches
# Match ratio: 6.0%
# Distance stats - Min: 0.14, Max: 0.39, Mean: 0.26
# Matching features: 4199 vs 4942 descriptors
# Found 269 good matches out of 4199 total matches
# Match ratio: 6.4%
# Distance stats - Min: 0.13, Max: 0.41, Mean: 0.25
# Matching features: 4199 vs 4621 descriptors
# Found 354 good matches out of 4199 total matches
# Match ratio: 8.4%
# Distance stats - Min: 0.13, Max: 0.41, Mean: 0.25
# Matching features: 4199 vs 4438 descriptors
# Found 380 good matches out of 4199 total matches
# Match ratio: 9.0%
# Distance stats - Min: 0.12, Max: 0.39, Mean: 0.25
# Matching features: 4199 vs 4425 descriptors
# Found 382 good matches out of 4199 total matches
# Match ratio: 9.1%
# Distance stats - Min: 0.12, Max: 0.38, Mean: 0.25
# Matching features: 4199 vs 4712 descriptors
# Found 328 good matches out of 4199 total matches
# Match ratio: 7.8%
# Distance stats - Min: 0.12, Max: 0.41, Mean: 0.25
# Matching features: 4199 vs 4903 descriptors
# Found 368 good matches out of 4199 total matches
# Match ratio: 8.8%
# Distance stats - Min: 0.11, Max: 0.40, Mean: 0.25
# Matching features: 4199 vs 4197 descriptors
# Found 348 good matches out of 4199 total matches
# Match ratio: 8.3%
# Distance stats - Min: 0.11, Max: 0.43, Mean: 0.25
# Matching features: 4486 vs 4858 descriptors
# Found 603 good matches out of 4486 total matches
# Match ratio: 13.4%
# Distance stats - Min: 0.11, Max: 0.38, Mean: 0.23
# Matching features: 4486 vs 4490 descriptors
# Found 729 good matches out of 4486 total matches
# Match ratio: 16.3%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.22
# Matching features: 4486 vs 4199 descriptors
# Found 1018 good matches out of 4486 total matches
# Match ratio: 22.7%
# Distance stats - Min: 0.07, Max: 0.44, Mean: 0.20
# Matching features: 4486 vs 4835 descriptors
# Found 1256 good matches out of 4486 total matches
# Match ratio: 28.0%
# Distance stats - Min: 0.06, Max: 0.40, Mean: 0.19
# Matching features: 4486 vs 4578 descriptors
# Found 895 good matches out of 4486 total matches
# Match ratio: 20.0%
# Distance stats - Min: 0.06, Max: 0.40, Mean: 0.22
# Matching features: 4486 vs 4677 descriptors
# Found 691 good matches out of 4486 total matches
# Match ratio: 15.4%
# Distance stats - Min: 0.09, Max: 0.43, Mean: 0.23
# Matching features: 4486 vs 4977 descriptors
# Found 606 good matches out of 4486 total matches
# Match ratio: 13.5%
# Distance stats - Min: 0.08, Max: 0.42, Mean: 0.23
# Matching features: 4486 vs 4402 descriptors
# Found 920 good matches out of 4486 total matches
# Match ratio: 20.5%
# Distance stats - Min: 0.06, Max: 0.40, Mean: 0.22
# Matching features: 4486 vs 5041 descriptors
# Found 967 good matches out of 4486 total matches
# Match ratio: 21.6%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.21
# Matching features: 4486 vs 4295 descriptors
# Found 1097 good matches out of 4486 total matches
# Match ratio: 24.5%
# Distance stats - Min: 0.06, Max: 0.41, Mean: 0.20
# Matching features: 4486 vs 4957 descriptors
# Found 880 good matches out of 4486 total matches
# Match ratio: 19.6%
# Distance stats - Min: 0.08, Max: 0.39, Mean: 0.22
# Matching features: 4486 vs 4838 descriptors
# Found 632 good matches out of 4486 total matches
# Match ratio: 14.1%
# Distance stats - Min: 0.09, Max: 0.40, Mean: 0.23
# Matching features: 4486 vs 5006 descriptors
# Found 446 good matches out of 4486 total matches
# Match ratio: 9.9%
# Distance stats - Min: 0.11, Max: 0.39, Mean: 0.24
# Matching features: 4486 vs 4929 descriptors
# Found 334 good matches out of 4486 total matches
# Match ratio: 7.4%
# Distance stats - Min: 0.12, Max: 0.41, Mean: 0.25
# Matching features: 4486 vs 4784 descriptors
# Found 243 good matches out of 4486 total matches
# Match ratio: 5.4%
# Distance stats - Min: 0.13, Max: 0.39, Mean: 0.26
# Matching features: 4486 vs 4887 descriptors
# Found 313 good matches out of 4486 total matches
# Match ratio: 7.0%
# Distance stats - Min: 0.13, Max: 0.41, Mean: 0.25
# Matching features: 4486 vs 4640 descriptors
# Found 415 good matches out of 4486 total matches
# Match ratio: 9.3%
# Distance stats - Min: 0.09, Max: 0.40, Mean: 0.24
# Matching features: 4486 vs 4929 descriptors
# Found 516 good matches out of 4486 total matches
# Match ratio: 11.5%
# Distance stats - Min: 0.09, Max: 0.40, Mean: 0.24
# Matching features: 4486 vs 4624 descriptors
# Found 713 good matches out of 4486 total matches
# Match ratio: 15.9%
# Distance stats - Min: 0.08, Max: 0.42, Mean: 0.23
# Matching features: 4486 vs 4866 descriptors
# Found 798 good matches out of 4486 total matches
# Match ratio: 17.8%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.22
# Matching features: 4486 vs 4692 descriptors
# Found 704 good matches out of 4486 total matches
# Match ratio: 15.7%
# Distance stats - Min: 0.09, Max: 0.42, Mean: 0.23
# Matching features: 4486 vs 4462 descriptors
# Found 863 good matches out of 4486 total matches
# Match ratio: 19.2%
# Distance stats - Min: 0.07, Max: 0.45, Mean: 0.22
# Matching features: 4486 vs 4293 descriptors
# Found 747 good matches out of 4486 total matches
# Match ratio: 16.7%
# Distance stats - Min: 0.08, Max: 0.41, Mean: 0.23
# Matching features: 4486 vs 4232 descriptors
# Found 663 good matches out of 4486 total matches
# Match ratio: 14.8%
# Distance stats - Min: 0.09, Max: 0.38, Mean: 0.23
# Matching features: 4486 vs 4534 descriptors
# Found 599 good matches out of 4486 total matches
# Match ratio: 13.4%
# Distance stats - Min: 0.08, Max: 0.44, Mean: 0.23
# Matching features: 4486 vs 4377 descriptors
# Found 673 good matches out of 4486 total matches
# Match ratio: 15.0%
# Distance stats - Min: 0.09, Max: 0.40, Mean: 0.23
# Matching features: 4486 vs 4844 descriptors
# Found 583 good matches out of 4486 total matches
# Match ratio: 13.0%
# Distance stats - Min: 0.10, Max: 0.39, Mean: 0.24
# Matching features: 4486 vs 4875 descriptors
# Found 509 good matches out of 4486 total matches
# Match ratio: 11.3%
# Distance stats - Min: 0.08, Max: 0.40, Mean: 0.24
# Matching features: 4486 vs 5235 descriptors
# Found 489 good matches out of 4486 total matches
# Match ratio: 10.9%
# Distance stats - Min: 0.10, Max: 0.41, Mean: 0.24
# Matching features: 4486 vs 4745 descriptors
# Found 459 good matches out of 4486 total matches
# Match ratio: 10.2%
# Distance stats - Min: 0.12, Max: 0.44, Mean: 0.25
# Matching features: 4486 vs 4777 descriptors
# Found 399 good matches out of 4486 total matches
# Match ratio: 8.9%
# Distance stats - Min: 0.10, Max: 0.43, Mean: 0.24
# Matching features: 4486 vs 4941 descriptors
# Found 299 good matches out of 4486 total matches
# Match ratio: 6.7%
# Distance stats - Min: 0.13, Max: 0.41, Mean: 0.26
# Matching features: 4486 vs 4985 descriptors
# Found 190 good matches out of 4486 total matches
# Match ratio: 4.2%
# Distance stats - Min: 0.12, Max: 0.38, Mean: 0.27
# Matching features: 4486 vs 5192 descriptors
# Found 204 good matches out of 4486 total matches
# Match ratio: 4.5%
# Distance stats - Min: 0.15, Max: 0.39, Mean: 0.27
# Matching features: 4486 vs 4925 descriptors
# Found 394 good matches out of 4486 total matches
# Match ratio: 8.8%
# Distance stats - Min: 0.13, Max: 0.39, Mean: 0.25
# Matching features: 4486 vs 4762 descriptors
# Found 487 good matches out of 4486 total matches
# Match ratio: 10.9%
# Distance stats - Min: 0.09, Max: 0.43, Mean: 0.24
# Matching features: 4486 vs 4617 descriptors
# Found 548 good matches out of 4486 total matches
# Match ratio: 12.2%
# Distance stats - Min: 0.09, Max: 0.44, Mean: 0.24
# Matching features: 4486 vs 4564 descriptors
# Found 592 good matches out of 4486 total matches
# Match ratio: 13.2%
# Distance stats - Min: 0.09, Max: 0.41, Mean: 0.24
# Matching features: 4486 vs 4324 descriptors
# Found 646 good matches out of 4486 total matches
# Match ratio: 14.4%
# Distance stats - Min: 0.10, Max: 0.41, Mean: 0.23
# Matching features: 4486 vs 4498 descriptors
# Found 634 good matches out of 4486 total matches
# Match ratio: 14.1%
# Distance stats - Min: 0.09, Max: 0.41, Mean: 0.23
# Matching features: 4486 vs 4798 descriptors
# Found 636 good matches out of 4486 total matches
# Match ratio: 14.2%
# Distance stats - Min: 0.09, Max: 0.40, Mean: 0.24
# Matching features: 4486 vs 4021 descriptors
# Found 517 good matches out of 4486 total matches
# Match ratio: 11.5%
# Distance stats - Min: 0.11, Max: 0.38, Mean: 0.23
# Matching features: 4486 vs 4327 descriptors
# Found 480 good matches out of 4486 total matches
# Match ratio: 10.7%
# Distance stats - Min: 0.09, Max: 0.43, Mean: 0.24
# Matching features: 4486 vs 4813 descriptors
# Found 444 good matches out of 4486 total matches
# Match ratio: 9.9%
# Distance stats - Min: 0.11, Max: 0.40, Mean: 0.25
# Matching features: 4486 vs 4483 descriptors
# Found 468 good matches out of 4486 total matches
# Match ratio: 10.4%
# Distance stats - Min: 0.07, Max: 0.41, Mean: 0.25
# Matching features: 4486 vs 4460 descriptors
# Found 473 good matches out of 4486 total matches
# Match ratio: 10.5%
# Distance stats - Min: 0.10, Max: 0.39, Mean: 0.25
# Matching features: 4486 vs 4537 descriptors
# Found 486 good matches out of 4486 total matches
# Match ratio: 10.8%
# Distance stats - Min: 0.10, Max: 0.42, Mean: 0.24
# Matching features: 4486 vs 4610 descriptors
# Found 475 good matches out of 4486 total matches
# Match ratio: 10.6%
# Distance stats - Min: 0.10, Max: 0.37, Mean: 0.24
# Matching features: 4486 vs 4560 descriptors
# Found 436 good matches out of 4486 total matches
# Match ratio: 9.7%
# Distance stats - Min: 0.09, Max: 0.39, Mean: 0.24
# Matching features: 4486 vs 4816 descriptors
# Found 361 good matches out of 4486 total matches
# Match ratio: 8.0%
# Distance stats - Min: 0.12, Max: 0.41, Mean: 0.25
# Matching features: 4486 vs 4342 descriptors
# Found 325 good matches out of 4486 total matches
# Match ratio: 7.2%
# Distance stats - Min: 0.12, Max: 0.42, Mean: 0.25
# Matching features: 4486 vs 4782 descriptors
# Found 153 good matches out of 4486 total matches
# Match ratio: 3.4%
# Distance stats - Min: 0.16, Max: 0.41, Mean: 0.27
# Matching features: 4486 vs 4795 descriptors
# Found 184 good matches out of 4486 total matches
# Match ratio: 4.1%
# Distance stats - Min: 0.14, Max: 0.43, Mean: 0.27
# Matching features: 4486 vs 4980 descriptors
# Found 175 good matches out of 4486 total matches
# Match ratio: 3.9%
# Distance stats - Min: 0.15, Max: 0.38, Mean: 0.27
# Matching features: 4486 vs 4942 descriptors
# Found 244 good matches out of 4486 total matches
# Match ratio: 5.4%
# Distance stats - Min: 0.14, Max: 0.39, Mean: 0.26
# Matching features: 4486 vs 4621 descriptors
# Found 276 good matches out of 4486 total matches
# Match ratio: 6.2%
# Distance stats - Min: 0.13, Max: 0.40, Mean: 0.26
# Matching features: 4486 vs 4438 descriptors
# Found 295 good matches out of 4486 total matches
# Match ratio: 6.6%
# Distance stats - Min: 0.13, Max: 0.39, Mean: 0.25
# Matching features: 4486 vs 4425 descriptors
# Found 352 good matches out of 4486 total matches
# Match ratio: 7.8%
# Distance stats - Min: 0.13, Max: 0.42, Mean: 0.26
# Matching features: 4486 vs 4712 descriptors
# Found 318 good matches out of 4486 total matches
# Match ratio: 7.1%
# Distance stats - Min: 0.12, Max: 0.42, Mean: 0.25
# Matching features: 4486 vs 4903 descriptors
# Found 354 good matches out of 4486 total matches
# Match ratio: 7.9%
# Distance stats - Min: 0.13, Max: 0.40, Mean: 0.25
# Matching features: 4486 vs 4197 descriptors
# Found 305 good matches out of 4486 total matches
# Match ratio: 6.8%
# Distance stats - Min: 0.12, Max: 0.38, Mean: 0.25
# Matching features: 4835 vs 4858 descriptors
# Found 466 good matches out of 4835 total matches
# Match ratio: 9.6%
# Distance stats - Min: 0.11, Max: 0.39, Mean: 0.24
# Matching features: 4835 vs 4490 descriptors
# Found 599 good matches out of 4835 total matches
# Match ratio: 12.4%
# Distance stats - Min: 0.08, Max: 0.43, Mean: 0.23
# Matching features: 4835 vs 4199 descriptors
# Found 748 good matches out of 4835 total matches
# Match ratio: 15.5%
# Distance stats - Min: 0.07, Max: 0.43, Mean: 0.22
# Matching features: 4835 vs 4486 descriptors
# Found 1227 good matches out of 4835 total matches
# Match ratio: 25.4%
# Distance stats - Min: 0.06, Max: 0.42, Mean: 0.19
# Matching features: 4835 vs 4578 descriptors
# Found 1254 good matches out of 4835 total matches
# Match ratio: 25.9%
# Distance stats - Min: 0.05, Max: 0.39, Mean: 0.19
# Matching features: 4835 vs 4677 descriptors
# Found 1012 good matches out of 4835 total matches
# Match ratio: 20.9%
# Distance stats - Min: 0.07, Max: 0.43, Mean: 0.21
# Matching features: 4835 vs 4977 descriptors
# Found 794 good matches out of 4835 total matches
# Match ratio: 16.4%
# Distance stats - Min: 0.07, Max: 0.42, Mean: 0.22
# Matching features: 4835 vs 4402 descriptors
# Found 1055 good matches out of 4835 total matches
# Match ratio: 21.8%
# Distance stats - Min: 0.07, Max: 0.42, Mean: 0.21
# Matching features: 4835 vs 5041 descriptors
# Found 1049 good matches out of 4835 total matches
# Match ratio: 21.7%
# Distance stats - Min: 0.07, Max: 0.39, Mean: 0.21
# Matching features: 4835 vs 4295 descriptors
# Found 902 good matches out of 4835 total matches
# Match ratio: 18.7%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.21
# Matching features: 4835 vs 4957 descriptors
# Found 690 good matches out of 4835 total matches
# Match ratio: 14.3%
# Distance stats - Min: 0.10, Max: 0.39, Mean: 0.23
# Matching features: 4835 vs 4838 descriptors
# Found 468 good matches out of 4835 total matches
# Match ratio: 9.7%
# Distance stats - Min: 0.10, Max: 0.40, Mean: 0.24
# Matching features: 4835 vs 5006 descriptors
# Found 346 good matches out of 4835 total matches
# Match ratio: 7.2%
# Distance stats - Min: 0.13, Max: 0.39, Mean: 0.25
# Matching features: 4835 vs 4929 descriptors
# Found 264 good matches out of 4835 total matches
# Match ratio: 5.5%
# Distance stats - Min: 0.13, Max: 0.40, Mean: 0.26
# Matching features: 4835 vs 4784 descriptors
# Found 191 good matches out of 4835 total matches
# Match ratio: 4.0%
# Distance stats - Min: 0.12, Max: 0.37, Mean: 0.26
# Matching features: 4835 vs 4887 descriptors
# Found 254 good matches out of 4835 total matches
# Match ratio: 5.3%
# Distance stats - Min: 0.09, Max: 0.43, Mean: 0.25
# Matching features: 4835 vs 4640 descriptors
# Found 361 good matches out of 4835 total matches
# Match ratio: 7.5%
# Distance stats - Min: 0.11, Max: 0.39, Mean: 0.24
# Matching features: 4835 vs 4929 descriptors
# Found 389 good matches out of 4835 total matches
# Match ratio: 8.0%
# Distance stats - Min: 0.12, Max: 0.40, Mean: 0.25
# Matching features: 4835 vs 4624 descriptors
# Found 556 good matches out of 4835 total matches
# Match ratio: 11.5%
# Distance stats - Min: 0.09, Max: 0.44, Mean: 0.24
# Matching features: 4835 vs 4866 descriptors
# Found 707 good matches out of 4835 total matches
# Match ratio: 14.6%
# Distance stats - Min: 0.09, Max: 0.40, Mean: 0.23
# Matching features: 4835 vs 4692 descriptors
# Found 680 good matches out of 4835 total matches
# Match ratio: 14.1%
# Distance stats - Min: 0.09, Max: 0.42, Mean: 0.23
# Matching features: 4835 vs 4462 descriptors
# Found 947 good matches out of 4835 total matches
# Match ratio: 19.6%
# Distance stats - Min: 0.07, Max: 0.42, Mean: 0.22
# Matching features: 4835 vs 4293 descriptors
# Found 777 good matches out of 4835 total matches
# Match ratio: 16.1%
# Distance stats - Min: 0.09, Max: 0.42, Mean: 0.22
# Matching features: 4835 vs 4232 descriptors
# Found 758 good matches out of 4835 total matches
# Match ratio: 15.7%
# Distance stats - Min: 0.09, Max: 0.42, Mean: 0.23
# Matching features: 4835 vs 4534 descriptors
# Found 704 good matches out of 4835 total matches
# Match ratio: 14.6%
# Distance stats - Min: 0.10, Max: 0.43, Mean: 0.23
# Matching features: 4835 vs 4377 descriptors
# Found 680 good matches out of 4835 total matches
# Match ratio: 14.1%
# Distance stats - Min: 0.08, Max: 0.38, Mean: 0.22
# Matching features: 4835 vs 4844 descriptors
# Found 574 good matches out of 4835 total matches
# Match ratio: 11.9%
# Distance stats - Min: 0.07, Max: 0.41, Mean: 0.23
# Matching features: 4835 vs 4875 descriptors
# Found 455 good matches out of 4835 total matches
# Match ratio: 9.4%
# Distance stats - Min: 0.10, Max: 0.40, Mean: 0.24
# Matching features: 4835 vs 5235 descriptors
# Found 417 good matches out of 4835 total matches
# Match ratio: 8.6%
# Distance stats - Min: 0.10, Max: 0.39, Mean: 0.25
# Matching features: 4835 vs 4745 descriptors
# Found 375 good matches out of 4835 total matches
# Match ratio: 7.8%
# Distance stats - Min: 0.10, Max: 0.38, Mean: 0.25
# Matching features: 4835 vs 4777 descriptors
# Found 307 good matches out of 4835 total matches
# Match ratio: 6.3%
# Distance stats - Min: 0.13, Max: 0.39, Mean: 0.25
# Matching features: 4835 vs 4941 descriptors
# Found 209 good matches out of 4835 total matches
# Match ratio: 4.3%
# Distance stats - Min: 0.12, Max: 0.38, Mean: 0.27
# Matching features: 4835 vs 4985 descriptors
# Found 162 good matches out of 4835 total matches
# Match ratio: 3.4%
# Distance stats - Min: 0.12, Max: 0.44, Mean: 0.26
# Matching features: 4835 vs 5192 descriptors
# Found 150 good matches out of 4835 total matches
# Match ratio: 3.1%
# Distance stats - Min: 0.15, Max: 0.35, Mean: 0.26
# Matching features: 4835 vs 4925 descriptors
# Found 335 good matches out of 4835 total matches
# Match ratio: 6.9%
# Distance stats - Min: 0.13, Max: 0.39, Mean: 0.26
# Matching features: 4835 vs 4762 descriptors
# Found 395 good matches out of 4835 total matches
# Match ratio: 8.2%
# Distance stats - Min: 0.10, Max: 0.38, Mean: 0.24
# Matching features: 4835 vs 4617 descriptors
# Found 508 good matches out of 4835 total matches
# Match ratio: 10.5%
# Distance stats - Min: 0.10, Max: 0.40, Mean: 0.24
# Matching features: 4835 vs 4564 descriptors
# Found 575 good matches out of 4835 total matches
# Match ratio: 11.9%
# Distance stats - Min: 0.10, Max: 0.41, Mean: 0.23
# Matching features: 4835 vs 4324 descriptors
# Found 635 good matches out of 4835 total matches
# Match ratio: 13.1%
# Distance stats - Min: 0.08, Max: 0.39, Mean: 0.23
# Matching features: 4835 vs 4498 descriptors
# Found 651 good matches out of 4835 total matches
# Match ratio: 13.5%
# Distance stats - Min: 0.08, Max: 0.41, Mean: 0.23
# Matching features: 4835 vs 4798 descriptors
# Found 660 good matches out of 4835 total matches
# Match ratio: 13.7%
# Distance stats - Min: 0.08, Max: 0.41, Mean: 0.23
# Matching features: 4835 vs 4021 descriptors
# Found 573 good matches out of 4835 total matches
# Match ratio: 11.9%
# Distance stats - Min: 0.07, Max: 0.40, Mean: 0.23
# Matching features: 4835 vs 4327 descriptors
# Found 539 good matches out of 4835 total matches
# Match ratio: 11.1%
# Distance stats - Min: 0.10, Max: 0.38, Mean: 0.24
# Matching features: 4835 vs 4813 descriptors
# Found 492 good matches out of 4835 total matches
# Match ratio: 10.2%
# Distance stats - Min: 0.09, Max: 0.40, Mean: 0.24
# Matching features: 4835 vs 4483 descriptors
# Found 504 good matches out of 4835 total matches
# Match ratio: 10.4%
# Distance stats - Min: 0.09, Max: 0.41, Mean: 0.24
# Matching features: 4835 vs 4460 descriptors
# Found 481 good matches out of 4835 total matches
# Match ratio: 9.9%
# Distance stats - Min: 0.09, Max: 0.45, Mean: 0.24
# Matching features: 4835 vs 4537 descriptors
# Found 495 good matches out of 4835 total matches
# Match ratio: 10.2%
# Distance stats - Min: 0.09, Max: 0.41, Mean: 0.24
# Matching features: 4835 vs 4610 descriptors
# Found 465 good matches out of 4835 total matches
# Match ratio: 9.6%
# Distance stats - Min: 0.09, Max: 0.41, Mean: 0.24
# Matching features: 4835 vs 4560 descriptors
# Found 395 good matches out of 4835 total matches
# Match ratio: 8.2%
# Distance stats - Min: 0.12, Max: 0.39, Mean: 0.25
# Matching features: 4835 vs 4816 descriptors
# Found 336 good matches out of 4835 total matches
# Match ratio: 6.9%
# Distance stats - Min: 0.11, Max: 0.38, Mean: 0.25
# Matching features: 4835 vs 4342 descriptors
# Found 279 good matches out of 4835 total matches
# Match ratio: 5.8%
# Distance stats - Min: 0.11, Max: 0.40, Mean: 0.26
# Matching features: 4835 vs 4782 descriptors
# Found 139 good matches out of 4835 total matches
# ...
# [Geo] final inliers: 666
# [Geo] E-inliers: 818/948
# [Geo] H-inliers: 72/818  ratio=0.09
# [Geo] Pose-inliers: 817/818
# [Geo] final inliers: 817
# [Geo] E-inliers: 834/1064
# [Geo] H-inliers: 94/834  ratio=0.11
# [Geo] Pose-inliers: 834/834
# [Geo] final inliers: 834
# [Geo] E-inliers: 817/1131
# [Geo] H-inliers: 94/817  ratio=0.12
# [Geo] Pose-inliers: 817/817
# [Geo] final inliers: 817
# [Geo] E-inliers: 908/1127
# [Geo] H-inliers: 88/908  ratio=0.10
# [Geo] Pose-inliers: 889/908
# [Geo] final inliers: 889
# [Geo] E-inliers: 919/1084
# [Geo] H-inliers: 80/919  ratio=0.09
# [Geo] Pose-inliers: 901/919
# [Geo] final inliers: 901
# [Geo] E-inliers: 752/862
# [Geo] H-inliers: 50/752  ratio=0.07
# [Geo] Pose-inliers: 751/752
# [Geo] final inliers: 751
# [Geo] E-inliers: 601/706
# [Geo] H-inliers: 47/601  ratio=0.08
# [Geo] Pose-inliers: 601/601
# [Geo] final inliers: 601
# [Geo] E-inliers: 382/504
# [Geo] H-inliers: 30/382  ratio=0.08
# [Geo] H-inliers: 18/152  ratio=0.12
# [Geo] Pose-inliers: 152/152
# [Geo] final inliers: 152
# [Geo] E-inliers: 183/236
# [Geo] H-inliers: 21/183  ratio=0.11
# [Geo] Pose-inliers: 183/183
# [Geo] final inliers: 183
# [Geo] E-inliers: 268/305
# [Geo] H-inliers: 32/268  ratio=0.12
# [Geo] Pose-inliers: 268/268
# [Geo] final inliers: 268
# [Geo] E-inliers: 319/408
# [Geo] H-inliers: 27/319  ratio=0.08
# [Geo] Pose-inliers: 319/319
# [Geo] final inliers: 319
# [Geo] E-inliers: 471/573
# [Geo] H-inliers: 41/471  ratio=0.09
# [Geo] Pose-inliers: 471/471
# [Geo] final inliers: 471
# [Geo] E-inliers: 659/797
# [Geo] H-inliers: 58/659  ratio=0.09
# [Geo] Pose-inliers: 659/659
# [Geo] final inliers: 659
# [Geo] E-inliers: 864/1024
# [Geo] H-inliers: 107/864  ratio=0.12
# [Geo] Pose-inliers: 864/864
# [Geo] final inliers: 864
# [Geo] E-inliers: 896/1047
# [Geo] H-inliers: 94/896  ratio=0.10
# [Geo] Pose-inliers: 891/896
# [Geo] final inliers: 891
# [Geo] E-inliers: 1346/1499
# [Geo] H-inliers: 203/1346  ratio=0.15
# [Geo] Pose-inliers: 1216/1346
# [Geo] final inliers: 1216

# %% [markdown]
# ## Cell 4: Initial Pose Estimation

# %%
def initialize_reconstruction(K: np.ndarray,
                              al_matches: List[List[List[cv2.DMatch]]],
                              features: List[Tuple[List[cv2.KeyPoint], np.ndarray]]):
    print("Estimating initial pose...")
    keypoints = [kp for kp, _ in features]
    i, j, R, t, inliers = pick_initial_pair(K, al_matches, keypoints=keypoints)
    print(f"Initial pair: {i}, {j}")
    print_pose_info(R, t, len(inliers), len(inliers))
    return i, j, R, t, inliers

init_i, init_j, R0, t0, init_inliers = initialize_reconstruction(K, al_matches, features)
print("Initial pair selected:", init_i, init_j)
# Out:
# Estimating initial pose...
# Initial pair: 3, 4
# ============================================================
# SCENE INITIALIZATION RESULTS
# ============================================================
#
# 1. Feature Matching:
#    - Total matches: 868
#    - Inlier matches: 868
#    - Inlier ratio: 1.000
#
# 2. Rotation Matrix (R):
# [[ 0.99909924 -0.00133618 -0.04241383]
#  [ 0.00254728  0.99959017  0.02851328]
#  [ 0.04235835 -0.02859564  0.99869318]]
#
# 3. Translation Vector (t):
# [ 0.99590146 -0.0616777   0.06615242]
#
# 4. Rotation as Rodrigues vector: [-0.02856692 -0.04240459  0.00194258]
# 5. Rotation in degrees: [-1.63676411 -2.42960398  0.11130144]
# 6. Translation distance (normalized): 1.0000
# 7. Total rotation angle: 2.93 degrees
# ============================================================
# Initial pair selected: 3 4

# %%
# %% 
# 7. Triangulate initial 3D points between camera init_i (ID 0) and init_j (ID 1)
kp_i, _ = features[init_i]
kp_j, _ = features[init_j]


pts3d, valid_idxs = triangulate_points(
    init_inliers, 
    kp_i, 
    kp_j, 
    K,
    np.eye(3),                # cam0 是世界坐标
    np.zeros((3,1)),         
    R0, 
    t0
)

print(f"Triangulated {pts3d.shape[0]} 3D points from the initial pair.")


# 8. 构建点云字典和观测字典
#    points_3d: pid -> [x, y, z]
#    point_observations: pid -> {cam_idx: (u,v), ...}
points_3d = {}
point_observations = {}

for pid, match_idx in enumerate(valid_idxs):
    # match_idx 是 init_inliers 中的下标
    m = init_inliers[match_idx]
    # 存坐标
    points_3d[pid] = pts3d[pid]
    # 存图像观测
    pt_i = kp_i[m.queryIdx].pt
    pt_j = kp_j[m.trainIdx].pt
    point_observations[pid] = {
        init_i: pt_i,
        init_j: pt_j
    }

print(f"Built observations for {len(points_3d)} points.")
# Out:
# Triangulated 868 3D points from the initial pair.
# Built observations for 868 points.

# %%
obs_index = {}
for pid, match_idx in enumerate(valid_idxs):
    m = init_inliers[match_idx]
    obs_index[(init_i, m.queryIdx)] = pid
    obs_index[(init_j, m.trainIdx)] = pid

# %% [markdown]
# ## Cell 5: Incremental SfM Reconstruction

# %%
def generate_bounce_path(num_images: int, begin:int , step: int = 10) -> List[int]:
    """
    在[0, num_images-1] 上以 step 为步长折返行走，
    直到访问到所有索引为止。
    """
    visited = set()
    path = []
    pos = begin
    delta = step

    while len(visited) < num_images:
        # 折返逻辑
        if pos < 0:
            pos = -pos
            delta = -delta
        elif pos > num_images-1:
            pos = 2*(num_images-1) - pos
            delta = -delta

        # 记录
        if pos not in visited:
            visited.add(pos)
            path.append(pos)

        pos += delta

    return path

# 测试一下
order = generate_bounce_path(len(image_paths),begin=init_i , step=3)
print("访问顺序：", order)
# 例如： [0, 5, 10, 15, 19, 14, 9, 4, 0, 6, 12, 18, 23, ...]（直到覆盖所有）
# Out:
# 访问顺序： [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 59, 56, 53, 50, 47, 44, 41, 38, 35, 32, 29, 26, 23, 20, 17, 14, 11, 8, 5, 2, 1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 0]

# %%
anchor_idxs  = [init_i, init_j]
camera_poses = {
    init_i: {'R': np.eye(3), 't': np.zeros((3,1))},
    init_j: {'R': R0,        't': t0}
}
# points_3d, point_observations, obs_index 都已准备好

# 2. 准备可变顺序列表，从 init_i 开始
start = order.index(init_i)
order_list = order[start:]  # e.g. [init_i, next, next, ...]
# 我们用 idx_ptr 来遍历 order_list
idx_ptr = 1  

# 3. 增量主循环
while idx_ptr < len(order_list):
    prev_idx = order_list[idx_ptr - 1]
    curr_idx = order_list[idx_ptr]

    # 3.1 如果前一帧还没注册，直接删掉这帧
    if prev_idx not in camera_poses:
        print(f"跳过 {prev_idx}->{curr_idx}：没有已知位姿，移除 {curr_idx}")
        order_list.pop(idx_ptr)
        continue

    # 3.2 聚合所有 anchors 的 2D–3D 对应
    kp_curr, _ = features[curr_idx]
    img_pts, obj_pts, corr = [], [], []
    for anchor in anchor_idxs:
        kp_a, _ = features[anchor]
        for m in al_matches[anchor][curr_idx]:
            key = (anchor, m.queryIdx)
            if key in obs_index:
                pid = obs_index[key]
                img_pts.append(kp_curr[m.trainIdx].pt)
                obj_pts.append(points_3d[pid])
                corr.append(m)
    # 如果对应太少，删掉这帧
    if len(obj_pts) < 4:
        print(f"跳过 图 {curr_idx}：2D–3D 对应 < 4 ({len(obj_pts)})，移除 {curr_idx}")
        order_list.pop(idx_ptr)
        continue

    # 3.3 PnP 注册
    Rn, tn, inlier_mask = pnp_pose(img_pts, obj_pts, K)
    camera_poses[curr_idx] = {'R': Rn, 't': tn}
    print(f"注册帧 {curr_idx}：PnP 内点 {int(inlier_mask.sum())}/{len(obj_pts)}")

    # 3.4 多视图三角化
    new_pts = multi_view_triangulation(
        new_idx=curr_idx,
        anchor_idxs=anchor_idxs,
        features=features,
        al_matches=al_matches,
        camera_poses=camera_poses,
        points_3d=points_3d,
        K=K
    )

    # 3.5 更新全局点云和观测
    for pid, X, match_map in new_pts:
        points_3d[pid] = X
        obs = {}
        for cam_idx, m in match_map.items():
            kpt = m.trainIdx if cam_idx == curr_idx else m.queryIdx
            uv  = features[cam_idx][0][kpt].pt
            obs[cam_idx] = uv
            obs_index[(cam_idx, kpt)] = pid
        point_observations[pid] = obs
    print(f"  新增 {len(new_pts)} 点，总共 {len(points_3d)} 点")

    # 3.6 更新 anchor 队列（RFU：最近 5 帧）
    anchor_idxs.append(curr_idx)
    if len(anchor_idxs) > 5:
        dropped = anchor_idxs.pop(0)
        print(f"  anchor 满 {5}，丢弃最早帧 {dropped}")

    # 3.7 前进到下一帧
    idx_ptr += 1

print("增量重建完成")
print(f"相机数: {len(camera_poses)}, 三维点数: {len(points_3d)}")
# Out:
# 注册帧 6：PnP 内点 174286/718
#   新增 1311 点，总共 2179 点
# 注册帧 9：PnP 内点 771890/1350
#   新增 1776 点，总共 3955 点
# 注册帧 12：PnP 内点 416563/1048
#   新增 1302 点，总共 5257 点
# 注册帧 15：PnP 内点 168619/676
#   新增 930 点，总共 6187 点
#   anchor 满 5，丢弃最早帧 3
# 注册帧 18：PnP 内点 781524/1345
#   新增 1842 点，总共 8029 点
#   anchor 满 5，丢弃最早帧 4
# 注册帧 21：PnP 内点 1010701/1640
#   新增 1994 点，总共 10023 点
#   anchor 满 5，丢弃最早帧 6
# 注册帧 24：PnP 内点 932812/1594
#   新增 1934 点，总共 11957 点
#   anchor 满 5，丢弃最早帧 9
# 注册帧 27：PnP 内点 1413891/1816
#   新增 2268 点，总共 14225 点
#   anchor 满 5，丢弃最早帧 12
# 注册帧 30：PnP 内点 1372539/1886
#   新增 2326 点，总共 16551 点
#   anchor 满 5，丢弃最早帧 15
# 注册帧 33：PnP 内点 768808/1381
#   新增 1612 点，总共 18163 点
#   anchor 满 5，丢弃最早帧 18
# 注册帧 36：PnP 内点 2075164/2206
#   新增 2540 点，总共 20703 点
#   anchor 满 5，丢弃最早帧 21
# 注册帧 39：PnP 内点 3034591/2687
#   新增 3197 点，总共 23900 点
#   anchor 满 5，丢弃最早帧 24
# 注册帧 42：PnP 内点 2294734/2371
#   新增 2683 点，总共 26583 点
#   anchor 满 5，丢弃最早帧 27
# 注册帧 45：PnP 内点 2914586/2530
#   新增 3077 点，总共 29660 点
#   anchor 满 5，丢弃最早帧 30
# 注册帧 48：PnP 内点 4264079/3166
#   新增 3617 点，总共 33277 点
#   anchor 满 5，丢弃最早帧 33
# 注册帧 51：PnP 内点 2853444/2651
#   新增 2934 点，总共 36211 点
#   anchor 满 5，丢弃最早帧 36
# 注册帧 54：PnP 内点 1416039/1793
#   新增 2087 点，总共 38298 点
#   anchor 满 5，丢弃最早帧 39
# 注册帧 57：PnP 内点 4175294/3156
#   新增 3560 点，总共 41858 点
#   anchor 满 5，丢弃最早帧 42
# 注册帧 60：PnP 内点 3568920/3009
#   新增 3388 点，总共 45246 点
#   anchor 满 5，丢弃最早帧 45
# 注册帧 59：PnP 内点 4794999/3246
#   新增 3731 点，总共 48977 点
#   anchor 满 5，丢弃最早帧 48
# 注册帧 56：PnP 内点 5186922/3457
#   新增 4001 点，总共 52978 点
#   anchor 满 5，丢弃最早帧 51
# 注册帧 53：PnP 内点 1861811/2120
#   新增 2412 点，总共 55390 点
#   anchor 满 5，丢弃最早帧 54
# 注册帧 50：PnP 内点 4150114/3149
#   新增 3483 点，总共 58873 点
#   anchor 满 5，丢弃最早帧 57
# 注册帧 47：PnP 内点 4725591/3322
#   新增 3739 点，总共 62612 点
#   anchor 满 5，丢弃最早帧 60
# 注册帧 44：PnP 内点 3090239/2664
#   新增 3025 点，总共 65637 点
#   anchor 满 5，丢弃最早帧 59
# 注册帧 41：PnP 内点 3369824/2743
#   新增 3108 点，总共 68745 点
#   anchor 满 5，丢弃最早帧 56
# 注册帧 38：PnP 内点 4109580/3081
#   新增 3472 点，总共 72217 点
#   anchor 满 5，丢弃最早帧 53
# 注册帧 35：PnP 内点 2364575/2408
#   新增 2660 点，总共 74877 点
#   anchor 满 5，丢弃最早帧 50
# 注册帧 32：PnP 内点 818631/1381
#   新增 1668 点，总共 76545 点
#   anchor 满 5，丢弃最早帧 47
# 注册帧 29：PnP 内点 2162179/2304
#   新增 2601 点，总共 79146 点
#   anchor 满 5，丢弃最早帧 44
# 注册帧 26：PnP 内点 3005733/2757
#   新增 3104 点，总共 82250 点
#   anchor 满 5，丢弃最早帧 41
# 注册帧 23：PnP 内点 1911724/2121
#   新增 2433 点，总共 84683 点
#   anchor 满 5，丢弃最早帧 38
# 注册帧 20：PnP 内点 2540141/2520
#   新增 2887 点，总共 87570 点
#   anchor 满 5，丢弃最早帧 35
# 注册帧 17：PnP 内点 1836721/2162
#   新增 2625 点，总共 90195 点
#   anchor 满 5，丢弃最早帧 32
# 注册帧 14：PnP 内点 946306/1523
#   新增 1713 点，总共 91908 点
#   anchor 满 5，丢弃最早帧 29
# 注册帧 11：PnP 内点 1883742/2147
#   新增 2517 点，总共 94425 点
#   anchor 满 5，丢弃最早帧 26
# 注册帧 8：PnP 内点 1590906/2092
#   新增 2414 点，总共 96839 点
#   anchor 满 5，丢弃最早帧 23
# 注册帧 5：PnP 内点 1239070/1762
#   新增 2029 点，总共 98868 点
#   anchor 满 5，丢弃最早帧 20
# 注册帧 2：PnP 内点 1902659/2204
#   新增 2610 点，总共 101478 点
#   anchor 满 5，丢弃最早帧 17
# 注册帧 1：PnP 内点 2928947/2648
#   新增 3379 点，总共 104857 点
#   anchor 满 5，丢弃最早帧 14
# 注册帧 4：PnP 内点 3060620/2696
#   新增 3243 点，总共 108100 点
#   anchor 满 5，丢弃最早帧 11
# 注册帧 7：PnP 内点 2783685/2572
#   新增 2871 点，总共 110971 点
#   anchor 满 5，丢弃最早帧 8
# 注册帧 10：PnP 内点 3212327/2866
#   新增 3113 点，总共 114084 点
#   anchor 满 5，丢弃最早帧 5
# 注册帧 13：PnP 内点 1341322/1858
#   新增 2051 点，总共 116135 点
#   anchor 满 5，丢弃最早帧 2
# 注册帧 16：PnP 内点 675238/1276
#   新增 1537 点，总共 117672 点
#   anchor 满 5，丢弃最早帧 1
# 注册帧 19：PnP 内点 1920439/2177
#   新增 2616 点，总共 120288 点
#   anchor 满 5，丢弃最早帧 4
# 注册帧 22：PnP 内点 2398964/2494
#   新增 2835 点，总共 123123 点
#   anchor 满 5，丢弃最早帧 7
# 注册帧 25：PnP 内点 1835735/2207
#   新增 2561 点，总共 125684 点
#   anchor 满 5，丢弃最早帧 10
# 注册帧 28：PnP 内点 1718351/2020
#   新增 2396 点，总共 128080 点
#   anchor 满 5，丢弃最早帧 13
# 注册帧 31：PnP 内点 1960440/2265
#   新增 2747 点，总共 130827 点
#   anchor 满 5，丢弃最早帧 16
# 注册帧 34：PnP 内点 954250/1527
#   新增 1736 点，总共 132563 点
#   anchor 满 5，丢弃最早帧 19
# 注册帧 37：PnP 内点 2747532/2511
#   新增 2873 点，总共 135436 点
#   anchor 满 5，丢弃最早帧 22
# 注册帧 40：PnP 内点 3111896/2710
#   新增 3144 点，总共 138580 点
#   anchor 满 5，丢弃最早帧 25
# 注册帧 43：PnP 内点 1738382/2015
#   新增 2289 点，总共 140869 点
#   anchor 满 5，丢弃最早帧 28
# 注册帧 46：PnP 内点 3613762/2864
#   新增 3455 点，总共 144324 点
#   anchor 满 5，丢弃最早帧 31
# 注册帧 49：PnP 内点 3670791/3009
#   新增 3448 点，总共 147772 点
#   anchor 满 5，丢弃最早帧 34
# 注册帧 52：PnP 内点 632269/1250
#   新增 1369 点，总共 149141 点
#   anchor 满 5，丢弃最早帧 37
# 注册帧 55：PnP 内点 1767408/1984
#   新增 2394 点，总共 151535 点
#   anchor 满 5，丢弃最早帧 40
# 注册帧 58：PnP 内点 3760283/2988
#   新增 3439 点，总共 154974 点
#   anchor 满 5，丢弃最早帧 43
# 注册帧 61：PnP 内点 3001695/2626
#   新增 2960 点，总共 157934 点
#   anchor 满 5，丢弃最早帧 46
# 注册帧 0：PnP 内点 540520/1158
#   新增 1256 点，总共 159190 点
#   anchor 满 5，丢弃最早帧 49
# 增量重建完成
# 相机数: 62, 三维点数: 159190

# %%
poses = sorted(camera_poses.keys())
sorted_pids = sorted(points_3d.keys())
points = np.vstack([points_3d[pid].reshape(1,3) for pid in sorted_pids])
print(f"Converted to points array of shape {points.shape}")

# 2. 构造 cams 列表
cams = []
for idx in poses:
    cam = camera_poses[idx]
    T = np.eye(4, dtype=np.float32)
    T[:3, :3] = cam['R']
    T[:3,  3] = cam['t'].reshape(3,)
    cams.append(T)
print(f"Built {len(cams)} camera poses as 4×4 matrices")
# Out:
# Converted to points array of shape (159190, 3)
# Built 62 camera poses as 4×4 matrices

# %% [markdown]
# ## Cell 6: Recentering and Camera Matrices

# %%
def recenter_poses_and_points(
    poses: List[Dict[str, Any]],
    points_3d: np.ndarray,
    world_filename: str,
    paths: List[str]
) -> Tuple[List[Dict[str, np.ndarray]], np.ndarray]:
    """
    对相机位姿和三维点做“重心化”处理：
    - world_filename 对应的那台相机 将成为新的原点且朝向不变
    - 其它相机与三维点 都按 R_w*(X - t_w) 变换到新坐标系

    Args:
        poses: List of {'R': (3,3), 't': (3,)}，原始世界坐标系下的相机外参
        points_3d: (N_pts,3) ndarray，原始世界坐标系下的三维点
        world_filename: 要作为新世界原点的那张图的文件名（例如 image_paths[0] 的 basename）
        paths:     List of 对应的所有图片完整路径

    Returns:
        new_poses: List of {'R': (3,3), 't': (3,)}，重心化后的相机外参
        new_points: (N_pts,3) ndarray，重心化后的三维点坐标
    """
    # 找到 world 相机在 poses/paths 中的索引
    idx_world = next(
        i for i, p in enumerate(paths)
        if os.path.basename(p) == world_filename
    )
    R_w = poses[idx_world]['R']
    t_w = poses[idx_world]['t'].reshape(3,)

    # 1) 重心化相机位姿
    new_poses = []
    for pose in poses:
        R_k = pose['R']
        t_k = pose['t'].reshape(3,)

        # 新的旋转、平移
        Rk_new = R_k @ R_w.T
        tk_new = t_k - (Rk_new @ t_w)

        new_poses.append({'R': Rk_new, 't': tk_new})

    # 2) 重心化三维点：X' = R_w @ (X - t_w)
    #    points_3d: (N_pts,3) → (3, N_pts) → 变换 → (N_pts,3)
    shifted = points_3d - t_w[None, :]        # (N_pts,3)
    new_points = (R_w @ shifted.T).T         # (N_pts,3)

    return new_poses, new_points


sorted_pids = sorted(points_3d.keys())
points = np.vstack([points_3d[pid].reshape(1,3) for pid in sorted_pids])
world_filename = "DJI_20200223_163225_243.jpg"
# 2. 把 camera_poses 转成和 image_paths 一一对应的列表
poses_list = []
valid_paths = []
for idx, path in enumerate(image_paths):
    cam = camera_poses.get(idx)
    if cam is None:
        continue
    R = cam['R']
    t = cam['t'].reshape(3,)    # 从 (3,1) → (3,)
    poses_list.append({'R': R, 't': t})
    valid_paths.append(path)

# 3. 调用 recenter_poses_and_points
new_poses_list, new_points = recenter_poses_and_points(
    poses_list,
    points,
    world_filename,
    valid_paths
)

# 4. 把 new_poses_list 再转回和 camera_poses 格式一致的 dict
new_camera_poses = {}
for idx, pose in enumerate(new_poses_list):
    new_camera_poses[idx] = {
        'R': pose['R'],
        't': pose['t'].reshape(3,1)   # 恢复成 (3,1)
    }

# 5. 构造保存用的 cams 列表
from scipy.spatial.transform import Rotation as R_scipy
cams = []
for idx in sorted(new_camera_poses.keys()):
    cam = new_camera_poses[idx]
    T = np.eye(4, dtype=np.float32)
    T[:3,:3] = cam['R']
    T[:3, 3] = cam['t'].reshape(3,)
    cams.append(T)

# new_poses 是 [{'R':..., 't':...}, …]
# new_points 形状 (N_pts,3)

# %% [markdown]
# ## Cell 7: Bundle Adjustment

# %%
# 1) 按帧索引排序，构造相机齐次矩阵列表
sorted_cam_idxs = sorted(new_camera_poses.keys())
camera_matrices = []
for idx in sorted_cam_idxs:
    cam = new_camera_poses[idx]
    T = np.eye(4, dtype=np.float32)
    T[:3, :3] = cam['R']
    T[:3,  3] = cam['t'].reshape(3,)
    camera_matrices.append(T)
camera_matrices = np.stack(camera_matrices, axis=0)  # (N_cam,4,4)
print("相机矩阵形状:", camera_matrices.shape)

# 2) 把 points_3d 从 dict → (N_pt,3) ndarray
sorted_pt_ids = sorted(points_3d.keys())
ptid_to_idx = {pid:i for i,pid in enumerate(sorted_pt_ids)}
points_array = np.vstack([points_3d[pid].reshape(1,3) for pid in sorted_pt_ids])
points_array = points_array.astype(np.float32)       # (N_pt,3)
print("三维点数组形状:", points_array.shape)

# 3) 从 point_observations 拆出 obs_uv, camera_idxs, point_idxs
obs_uv      = []
camera_idxs = []
point_idxs  = []

for pid, cam_dict in point_observations.items():
    if pid not in ptid_to_idx:
        continue
    pt_idx = ptid_to_idx[pid]
    for cam_idx, uv in cam_dict.items():
        # 跳过那些未注册的相机
        if cam_idx not in new_camera_poses:
            continue
        # 把 cam_idx 转换到相机矩阵列表中的位置
        cam_list_idx = sorted_cam_idxs.index(cam_idx)
        obs_uv.append(uv)
        camera_idxs.append(cam_list_idx)
        point_idxs.append(pt_idx)

obs_uv      = np.array(obs_uv,      dtype=np.float32)  # (N_obs,2)
camera_idxs = np.array(camera_idxs, dtype=np.int64)    # (N_obs,)
point_idxs  = np.array(point_idxs,  dtype=np.int64)    # (N_obs,)
print("观测数量:", obs_uv.shape[0])

# 4) 构造并运行 Bundle Adjustment
ba = TorchBundleAdjustment(
    camera_intrinsics=K, 
    init_cameras=camera_matrices,
    init_points=points_array
)
opt_cams, opt_pts, info = ba.optimize(
    cameras=camera_matrices,
    points_3d=points_3d,
    observations=obs_uv,
    point_indices=point_idxs,
    camera_indices=camera_idxs
)
# Out:
# 相机矩阵形状: (62, 4, 4)
# 三维点数组形状: (159190, 3)
# 观测数量: 318380
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[1810.8936   372.45615]
#  [1713.7719  1625.0433 ]
#  [1945.84    1207.5424 ]], pred_uv: [[1499.4958   672.07605]
#  [1720.0085  1847.8972 ]
#  [1896.471   1434.3685 ]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[2201.3103 1065.931 ]
#  [1310.7118 1261.068 ]
#  [2185.686  1036.0724]], pred_uv: [[2142.6768 1306.1349]
#  [1198.7119 1507.7269]
#  [2152.2502 1281.0734]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[2578.036  2168.5989]
#  [2116.7737 1138.9869]
#  [2346.1487  627.4268]], pred_uv: [[2747.8218 2327.0747]
#  [2041.4653 1376.2097]
#  [1963.4558  922.0657]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[2108.3604 1073.846 ]
#  [1639.8662 1548.4565]
#  [2215.9038 1612.9213]], pred_uv: [[2040.4531 1301.4036]
#  [1632.3965 1763.8751]
#  [2315.9692 1788.7084]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[2115.8726 1269.8129]
#  [2025.4452 1144.5833]
#  [2176.4326 1186.0298]], pred_uv: [[2109.1504 1476.9216]
#  [1979.4121 1359.69  ]
#  [2124.3955 1414.4822]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[
]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[1440.6797 1136.4635]
#  [1738.4872 1587.4552]
#  [2027.3163 1101.8555]], pred_uv: [[1420.2222 1166.3195]
#  [1806.5942 1609.1475]
#  [2082.4868 1149.0251]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[ 781.0798  1716.4202 ]
#  [ 876.86383 1230.6389 ]
#  [ 624.63196 1132.5599 ]], pred_uv: [[ 742.67554 1762.2153 ]
#  [ 788.8511  1302.6763 ]
#  [ 541.19885 1136.0513 ]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[2196.8909  1097.2443 ]
#  [1301.0253   874.6952 ]
#  [ 616.09576 1326.4382 ]], pred_uv: [[2215.7874  1154.54   ]
#  [1234.1821   931.0759 ]
#  [ 541.36694 1327.3306 ]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[ 588.1204 1393.4822]
#  [2113.0762 1137.3881]
#  [2117.2644 1168.9767]], pred_uv: [[ 524.53174 1394.5552 ]
#  [2135.9983  1188.7601 ]
#  [2176.6062  1213.2335 ]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[1515.2264 1110.1903]
#  [2120.4946 1581.5176]
#  [1957.021  1185.4343]], pred_uv: [[1469.5037 1165.3827]
#  [2224.363  1581.8406]
#  [1997.1904 1236.2872]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[1682.6919  1315.4282 ]
#  [2496.7114   676.59955]
#  [2210.964   1121.3534 ]], pred_uv: [[1675.1355  1350.926  ]
#  [2523.745    745.33264]
#  [2221.8364  1155.5354 ]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[1566.6564   1209.6299  ]
#  [2166.7      1568.3777  ]
#  [  99.693405 2392.0535  ]], pred_uv: [[1569.6392  1239.8481 ]
#  [2327.0789  1567.6498 ]
#  [-495.06665 2578.055  ]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[1667.1346  1333.2612 ]
#  [1633.2754  1500.9255 ]
#  [ 225.43631 1615.6287 ]], pred_uv: [[1686.8293  1372.4305 ]
#  [1684.4109  1525.3251 ]
#  [ 143.68481 1639.27   ]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[2147.444   1143.4692 ]
#  [2298.852    682.58496]
#  [1712.5876  1640.1234 ]], pred_uv: [[2189.0286 1186.1093]
#  [2317.0466  771.1882]
#  [1780.1125 1651.0146]]
# [rodrigues] input rvecs shape: torch.Size([128, 3])
# [rodrigues] output R shape: torch.Size([128, 3, 3])
# [forward] batch obs_uv shape: torch.Size([128, 2]), pred_uv shape: torch.Size([128, 2])
# [forward] sample obs_uv: [[2317.6206   928.28015]
#  [ 724.3479  1488.3778 ]
#  [2624.854    504.3408 ]], pred_uv: [[2354.8496   980.59827]
#  [ 664.8911  1524.0875 ]
#  [2669.7754   568.6517 ]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 50
#      44 # 4) 构造并运行 Bundle Adjustment
#      45 ba = TorchBundleAdjustment(
#      46     camera_intrinsics=K,
#      47     init_cameras=camera_matrices,
#      48     init_points=points_array
#      49 )
# ---> 50 opt_cams, opt_pts, info = ba.optimize(
#      51     cameras=camera_matrices,
#      52     points_3d=points_3d,
#      53     observations=obs_uv,
#      54     point_indices=point_idxs,
#      55     camera_indices=camera_idxs
#      56 )
#
# File d:\lyz\Python\CV\AI4701\final project\code\bundle_adjustment.py:141, in TorchBundleAdjustment.optimize(self, cameras, points_3d, observations, point_indices, camera_indices, batch_size)
#     139 pred_uv = self(batch_obs, batch_cam, batch_pt)
#     140 loss    = (pred_uv - batch_obs).pow(2).sum()
# --> 141 loss.backward()
#     142 adam.step()
#     143 epoch_loss += loss.item()
#
# File c:\Users\19139\anaconda3\Lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File c:\Users\19139\anaconda3\Lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File c:\Users\19139\anaconda3\Lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Cell 8: Save Results

# %%
def save_outputs(points: np.ndarray, cameras: List[np.ndarray], output_dir: str):
    os.makedirs(output_dir, exist_ok=True)
    ply = os.path.join(output_dir, 'optimized_point_cloud.ply')
    with open(ply, 'w') as f:
        f.write('ply\nformat ascii 1.0\n')
        f.write(f'element vertex {points.shape[0]}\n')
        f.write('property float x\nproperty float y\nproperty float z\nend_header\n')
        for p in points:
            f.write(f"{p[0]} {p[1]} {p[2]}\n")
    traj = os.path.join(output_dir, 'optimized_camera_trajectory.txt')
    with open(traj, 'w') as f:
        f.write('# CamIdx tx ty tz qx qy qz qw\n')
        for i, T in enumerate(cameras):
            pos = T[:3,3]
            quat = R_scipy.from_matrix(T[:3,:3]).as_quat()
            f.write(f"{i} {pos[0]} {pos[1]} {pos[2]} {quat[0]} {quat[1]} {quat[2]} {quat[3]}\n")
    print(f"Saved PLY: {ply}\nSaved trajectory: {traj}")




save_outputs(points, cams, OUTPUT_DIR)
#save_outputs(opt_pts, opt_cams, OUTPUT_DIR)
# %%
# Out:
# Saved PLY: D:\lyz\Python\CV\AI4701\final project\output\optimized_point_cloud.ply
# Saved trajectory: D:\lyz\Python\CV\AI4701\final project\output\optimized_camera_trajectory.txt

# %% [markdown]
# ## Cell 9: Visualization

# %%
pcd = o3d.io.read_point_cloud(os.path.join(OUTPUT_DIR, 'optimized_point_cloud.ply'))
points = np.asarray(pcd.points)
poses_vis = []
with open(os.path.join(OUTPUT_DIR, 'optimized_camera_trajectory.txt'), 'r') as f:
    for line in f:
        if line.startswith('#'): continue
        parts = line.split()
        _, tx, ty, tz, qx, qy, qz, qw = parts
        Rm = R_scipy.from_quat([float(qx),float(qy),float(qz),float(qw)]).as_matrix()
        poses_vis.append({'R': Rm, 't': np.array([float(tx),float(ty),float(tz)]).reshape(3,1)})

print(f"Loaded {len(points)} points and {len(poses_vis)} cameras.")
visualize_with_open3d(points, poses_vis,show_cameras=True)

camera_mats = []
for pose in poses_vis:
    T = np.eye(4, dtype=np.float64)
    T[:3,:3] = pose['R']
    T[:3, 3] = pose['t'].reshape(3)
    camera_mats.append(T)
camera_mats = np.stack(camera_mats, axis=0)  # → (N_cam,4,4)

visualize_colored_point_cloud(points, camera_mats ,valid_paths ,K)
# Out:
# Loaded 159190 points and 62 cameras.

# %% [markdown]
# ## Cell 10: Evaluation

# %%
# 1) 计算重投影误差
errs = reprojection_errors(points_3d, camera_mats, K, obs_uv, cam_idxs, pt_idxs)
stats = reprojection_stats(errs)
print("Reproj error (px):", stats)

# 2) 点轨迹长度
track_stats = track_length_stats(point_observations)
print("Track lengths:", track_stats)

# 3) 图像覆盖度
cov_stats = image_coverage_stats(point_observations, camera_mats.shape[0])
print("Image coverage:", cov_stats)

# 4) 点/相机 比例
ratio = points_per_camera_ratio(points_3d, camera_mats)
print("Points/Cameras:", ratio)
